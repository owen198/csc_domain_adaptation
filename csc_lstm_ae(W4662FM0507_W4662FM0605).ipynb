# %% [markdown]
# <a href="https://colab.research.google.com/github/owen198/csc_domain_adaptation/blob/main/csc_lstm_ae(W4662FM0605).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# https://towardsdatascience.com/step-by-step-understanding-lstm-autoencoder-layers-ffab055b6352

from sklearn import preprocessing
from sklearn import svm
import pandas as pd
import datetime

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import random


from keras import metrics
from keras import models
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from keras.layers import Input, BatchNormalization, Activation
from keras.callbacks import EarlyStopping

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %% [markdown]
# # Load Data and proprecessing

# %%
tag_dict = {'source':'W4662FM0507',
            'source_training_from': datetime.datetime(2020,9,1,0,0),
            'source_training_to': datetime.datetime(2021,1,8,0,0),
            'source_end': datetime.datetime(2021,2,1,0,0),
            
            'target':'W4662FM0605',
            'target_training_from': datetime.datetime(2020,3,1,0,0), 
            'target_training_to': datetime.datetime(2020,4,1,0,0), 
            'target_end': datetime.datetime(2020,7,1,0,0)}

path = './gdrive/MyDrive/data/CSC/W4/'

# %%
globals()[tag_dict['target']] = pd.concat([pd.read_csv(path + tag_dict['target'] + '_202003.csv'),
                                          pd.read_csv(path + tag_dict['target'] + '_202004.csv'),
                                          pd.read_csv(path + tag_dict['target'] + '_202005.csv'),
                                          pd.read_csv(path + tag_dict['target'] + '_202006.csv'),
                                          pd.read_csv(path + tag_dict['target'] + '_202007.csv')])

globals()[tag_dict['source']] = pd.concat([pd.read_csv(path + tag_dict['source'] + '_202009.csv'),
                                          pd.read_csv(path + tag_dict['source'] + '_202010.csv'),
                                          pd.read_csv(path + tag_dict['source'] + '_202011.csv'),
                                          pd.read_csv(path + tag_dict['source'] + '_202012.csv'),
                                          pd.read_csv(path + tag_dict['source'] + '_202101.csv'),
                                          pd.read_csv(path + tag_dict['source'] + '_202102.csv')])

# %%
globals()[tag_dict['source']]['datetime'] = globals()[tag_dict['source']]['timestamp'].astype('int').astype("datetime64[s]")
globals()[tag_dict['target']]['datetime'] = globals()[tag_dict['target']]['timestamp'].astype('int').astype("datetime64[s]")

# %%
globals()[tag_dict['source']+'_training'] = globals()[tag_dict['source']][
                                                  (globals()[tag_dict['source']]['datetime'] > tag_dict['source_training_from']) &
                                                  (globals()[tag_dict['source']]['datetime'] <= tag_dict['source_training_to']) ]

globals()[tag_dict['target']+'_training'] = globals()[tag_dict['target']][
                                                  (globals()[tag_dict['target']]['datetime'] > tag_dict['target_training_from']) &
                                                  (globals()[tag_dict['target']]['datetime'] <= tag_dict['target_training_to']) ]

# %%
drop_list = ['Unnamed: 0', '_id','type','scada','timestamp','device', 'datetime']

globals()[tag_dict['source']+'_training'] = globals()[tag_dict['source']+'_training'].drop(columns=drop_list)
globals()[tag_dict['target']+'_training'] = globals()[tag_dict['target']+'_training'].drop(columns=drop_list)

# %%
shape_min = min (globals()[tag_dict['source']+'_training'].shape[0], 
                 globals()[tag_dict['target']+'_training'].shape[0])
shape_max = max (globals()[tag_dict['source']+'_training'].shape[0], 
                 globals()[tag_dict['target']+'_training'].shape[0])

index = sorted(random.sample(range(0, shape_max), shape_min))

# %%
normalizer = preprocessing.MinMaxScaler()
normalizer = normalizer.fit(globals()[tag_dict['source']+'_training'])

X_source = pd.DataFrame(normalizer.transform(globals()[tag_dict['source']+'_training']))
X_target = pd.DataFrame(normalizer.transform(globals()[tag_dict['target']+'_training']))

# %%
def temporalize(X, y, lookback):
    output_X = []
    output_y = []
    for i in range(len(X)-lookback-1):
        t = []
        for j in range(1,lookback+1):
            # Gather past records upto the lookback period
            t.append(X[[(i+j+1)], :])
        output_X.append(t)
        output_y.append(y[i+lookback+1])
    return output_X, output_y

# %%
if len(X_target) > len(X_source):
    X = X_target.iloc[index]
    Y = X_source
else:
    X = X_target
    Y = X_source.iloc[index]


timesteps = 4
n_features = 390

#X, y = temporalize(X = timeseries, y = np.zeros(len(timeseries)), lookback = timesteps)
X, _ = temporalize(X = X.values, y = np.zeros(len(X)), lookback = timesteps)
Y, _ = temporalize(X = Y.values, y = np.zeros(len(Y)), lookback = timesteps)

X = np.array(X)
X = X.reshape(X.shape[0], timesteps, n_features)

Y = np.array(Y)
Y = Y.reshape(np.array(Y).shape[0], timesteps, n_features)

# %% [markdown]
# # LSTM-AE Model

# %%
def lstm_ae():
    # define model
    model = Sequential()
    model.add(LSTM(64, activation='relu', input_shape=(timesteps,n_features), return_sequences=True))
    model.add(LSTM(16, activation='relu', return_sequences=False))
    model.add(RepeatVector(timesteps))
    model.add(LSTM(16, activation='relu', return_sequences=True))
    model.add(LSTM(64, activation='relu', return_sequences=True))
    model.add(TimeDistributed(Dense(n_features)))
    model.compile(optimizer='adam', loss='mse', metrics=[metrics.RootMeanSquaredError()])
    model.summary()

    return model

# %%
model_name = './gdrive/My Drive/data/CSC/W4/' + tag_dict['target'] + '_encoded'
model_name
# Out:
# './gdrive/My Drive/data/CSC/W4/W4662FM0605_encoded'

# %%
retrain = True


if retrain:
    early_stopping = EarlyStopping(monitor='val_loss', patience=150, verbose=2)

    model = lstm_ae ()
    lstm_ae_model = model.fit(Y, X, epochs=150, batch_size=16, verbose=1, validation_split=0.2, callbacks=[early_stopping])
    model.save(model_name)
else:
    model = models.load_model(model_name)  
    

#model = models.load_model(model_name)    
synthetic_data = model.predict(X, verbose=0)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 4, 64)             116480
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 16)                5184
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 4, 16)             0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 4, 16)             2112
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 4, 64)             20736
# _________________________________________________________________
# time_distributed (TimeDistri (None, 4, 390)            25350
# =================================================================
# Total params: 169,862
# Trainable params: 169,862
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/150
# 664/664 [==============================] - 15s 16ms/step - loss: 0.0876 - root_mean_squared_error: 0.2668 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0787
# Epoch 2/150
# 664/664 [==============================] - 9s 13ms/step - loss: 0.0083 - root_mean_squared_error: 0.0908 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0762
# Epoch 3/150
# 664/664 [==============================] - 8s 13ms/step - loss: 0.0076 - root_mean_squared_error: 0.0872 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0805
# Epoch 4/150
# 664/664 [==============================] - 9s 13ms/step - loss: 0.0063 - root_mean_squared_error: 0.0796 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0809
# Epoch 5/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0061 - root_mean_squared_error: 0.0779 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0755
# Epoch 6/150
# 664/664 [==============================] - 9s 13ms/step - loss: 0.0055 - root_mean_squared_error: 0.0744 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0783
# Epoch 7/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0053 - root_mean_squared_error: 0.0730 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0765
# Epoch 8/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0051 - root_mean_squared_error: 0.0714 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0720
# Epoch 9/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0050 - root_mean_squared_error: 0.0704 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0749
# Epoch 10/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0045 - root_mean_squared_error: 0.0667 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0739
# Epoch 11/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0044 - root_mean_squared_error: 0.0666 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0743
# Epoch 12/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0045 - root_mean_squared_error: 0.0669 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0741
# Epoch 13/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0043 - root_mean_squared_error: 0.0656 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0731
# Epoch 14/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0043 - root_mean_squared_error: 0.0655 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0755
# Epoch 15/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0040 - root_mean_squared_error: 0.0631 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0732
# Epoch 16/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0040 - root_mean_squared_error: 0.0635 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0761
# Epoch 17/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0039 - root_mean_squared_error: 0.0626 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0741
# Epoch 18/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0040 - root_mean_squared_error: 0.0630 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0769
# Epoch 19/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0039 - root_mean_squared_error: 0.0621 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0760
# Epoch 20/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0038 - root_mean_squared_error: 0.0613 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0763
# Epoch 21/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0036 - root_mean_squared_error: 0.0598 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0789
# Epoch 22/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0036 - root_mean_squared_error: 0.0602 - val_loss: 0.0068 - val_root_mean_squared_error: 0.0825
# Epoch 23/150
# 664/664 [==============================] - 12s 18ms/step - loss: 0.0036 - root_mean_squared_error: 0.0600 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0861
# Epoch 24/150
# 664/664 [==============================] - 10s 15ms/step - loss: 0.0035 - root_mean_squared_error: 0.0593 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0807
# Epoch 25/150
# 664/664 [==============================] - 9s 14ms/step - loss: 0.0034 - root_mean_squared_error: 0.0583 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0775
# Epoch 26/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0035 - root_mean_squared_error: 0.0588 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0793
# Epoch 27/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0033 - root_mean_squared_error: 0.0571 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0766
# Epoch 28/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0032 - root_mean_squared_error: 0.0565 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0746
# Epoch 29/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0033 - root_mean_squared_error: 0.0577 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0800
# Epoch 30/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0032 - root_mean_squared_error: 0.0569 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0789
# Epoch 31/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0032 - root_mean_squared_error: 0.0563 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0877
# Epoch 32/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0033 - root_mean_squared_error: 0.0575 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0835
# Epoch 33/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0031 - root_mean_squared_error: 0.0556 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0793
# Epoch 34/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0029 - root_mean_squared_error: 0.0540 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0798
# Epoch 35/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0032 - root_mean_squared_error: 0.0563 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0796
# Epoch 36/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0031 - root_mean_squared_error: 0.0558 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0816
# Epoch 37/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0030 - root_mean_squared_error: 0.0547 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0850
# Epoch 38/150
# 664/664 [==============================] - 9s 13ms/step - loss: 0.0029 - root_mean_squared_error: 0.0541 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0791
# Epoch 39/150
# 664/664 [==============================] - 10s 15ms/step - loss: 0.0030 - root_mean_squared_error: 0.0543 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0750
# Epoch 40/150
# 664/664 [==============================] - 9s 14ms/step - loss: 0.0029 - root_mean_squared_error: 0.0534 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0781
# Epoch 41/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0031 - root_mean_squared_error: 0.0552 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0810
# Epoch 42/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0027 - root_mean_squared_error: 0.0515 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0812
# Epoch 43/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0029 - root_mean_squared_error: 0.0539 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0785
# Epoch 44/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0027 - root_mean_squared_error: 0.0520 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0768
# Epoch 45/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0026 - root_mean_squared_error: 0.0513 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0787
# Epoch 46/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0028 - root_mean_squared_error: 0.0527 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0776
# Epoch 47/150
# 664/664 [==============================] - 8s 11ms/step - loss: 0.0030 - root_mean_squared_error: 0.0551 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0763
# Epoch 48/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0026 - root_mean_squared_error: 0.0510 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0800
# Epoch 49/150
# 664/664 [==============================] - 9s 13ms/step - loss: 0.0027 - root_mean_squared_error: 0.0517 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0776
# Epoch 50/150
# 664/664 [==============================] - 8s 13ms/step - loss: 0.0028 - root_mean_squared_error: 0.0525 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0829
# Epoch 51/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0026 - root_mean_squared_error: 0.0508 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0778
# Epoch 52/150
# 664/664 [==============================] - 8s 13ms/step - loss: 0.0027 - root_mean_squared_error: 0.0523 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0759
# Epoch 53/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0027 - root_mean_squared_error: 0.0518 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0803
# Epoch 54/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0027 - root_mean_squared_error: 0.0520 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0804
# Epoch 55/150
# 664/664 [==============================] - 8s 11ms/step - loss: 0.0026 - root_mean_squared_error: 0.0514 - val_loss: 0.0068 - val_root_mean_squared_error: 0.0825
# Epoch 56/150
# 664/664 [==============================] - 8s 11ms/step - loss: 0.0026 - root_mean_squared_error: 0.0505 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0792
# Epoch 57/150
# 664/664 [==============================] - 8s 11ms/step - loss: 0.0026 - root_mean_squared_error: 0.0510 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0773
# Epoch 58/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0025 - root_mean_squared_error: 0.0500 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0786
# Epoch 59/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0024 - root_mean_squared_error: 0.0491 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0801
# Epoch 60/150
# 664/664 [==============================] - 10s 15ms/step - loss: 0.0035 - root_mean_squared_error: 0.0589 - val_loss: 0.0068 - val_root_mean_squared_error: 0.0826
# Epoch 61/150
# 664/664 [==============================] - 10s 15ms/step - loss: 0.0031 - root_mean_squared_error: 0.0554 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0790
# Epoch 62/150
# 664/664 [==============================] - 9s 14ms/step - loss: 0.0030 - root_mean_squared_error: 0.0551 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0801
# Epoch 63/150
# 664/664 [==============================] - 9s 14ms/step - loss: 0.0025 - root_mean_squared_error: 0.0502 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0779
# Epoch 64/150
# 664/664 [==============================] - 8s 13ms/step - loss: 0.0028 - root_mean_squared_error: 0.0525 - val_loss: 0.0068 - val_root_mean_squared_error: 0.0824
# Epoch 65/150
# 664/664 [==============================] - 9s 13ms/step - loss: 0.0025 - root_mean_squared_error: 0.0502 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0787
# Epoch 66/150
# 664/664 [==============================] - 9s 13ms/step - loss: 0.0032 - root_mean_squared_error: 0.0564 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0801
# Epoch 67/150
# 664/664 [==============================] - 8s 13ms/step - loss: 0.0025 - root_mean_squared_error: 0.0503 - val_loss: 0.0068 - val_root_mean_squared_error: 0.0823
# Epoch 68/150
# 664/664 [==============================] - 9s 13ms/step - loss: 0.0026 - root_mean_squared_error: 0.0510 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0780
# Epoch 69/150
# 664/664 [==============================] - 8s 13ms/step - loss: 0.0025 - root_mean_squared_error: 0.0504 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0783
# Epoch 70/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0024 - root_mean_squared_error: 0.0494 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0799
# Epoch 71/150
# 664/664 [==============================] - 8s 13ms/step - loss: 0.0027 - root_mean_squared_error: 0.0520 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0798
# Epoch 72/150
# 664/664 [==============================] - 8s 13ms/step - loss: 0.0024 - root_mean_squared_error: 0.0490 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0798
# Epoch 73/150
# 664/664 [==============================] - 8s 13ms/step - loss: 0.0028 - root_mean_squared_error: 0.0528 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0829
# Epoch 74/150
# 664/664 [==============================] - 9s 13ms/step - loss: 0.0025 - root_mean_squared_error: 0.0499 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0772
# Epoch 75/150
# 664/664 [==============================] - 9s 14ms/step - loss: 0.0026 - root_mean_squared_error: 0.0509 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0819
# Epoch 76/150
# 664/664 [==============================] - 11s 16ms/step - loss: 0.0025 - root_mean_squared_error: 0.0495 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0809
# Epoch 77/150
# 664/664 [==============================] - 9s 14ms/step - loss: 0.0027 - root_mean_squared_error: 0.0517 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0791
# Epoch 78/150
# 664/664 [==============================] - 9s 14ms/step - loss: 0.0026 - root_mean_squared_error: 0.0512 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0780
# Epoch 79/150
# 664/664 [==============================] - 8s 13ms/step - loss: 0.0025 - root_mean_squared_error: 0.0501 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0810
# Epoch 80/150
# 664/664 [==============================] - 9s 13ms/step - loss: 0.0026 - root_mean_squared_error: 0.0506 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0828
# Epoch 81/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0024 - root_mean_squared_error: 0.0491 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0809
# Epoch 82/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0025 - root_mean_squared_error: 0.0499 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0780
# Epoch 83/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0024 - root_mean_squared_error: 0.0485 - val_loss: 0.0068 - val_root_mean_squared_error: 0.0823
# Epoch 84/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0028 - root_mean_squared_error: 0.0524 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0748
# Epoch 85/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0024 - root_mean_squared_error: 0.0493 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0801
# Epoch 86/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0025 - root_mean_squared_error: 0.0496 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0785
# Epoch 87/150
# 664/664 [==============================] - 8s 11ms/step - loss: 0.0028 - root_mean_squared_error: 0.0527 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0793
# Epoch 88/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0026 - root_mean_squared_error: 0.0511 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0787
# Epoch 89/150
# 664/664 [==============================] - 8s 11ms/step - loss: 0.0024 - root_mean_squared_error: 0.0492 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0818
# Epoch 90/150
# 664/664 [==============================] - 8s 11ms/step - loss: 0.0024 - root_mean_squared_error: 0.0486 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0790
# Epoch 91/150
# 664/664 [==============================] - 7s 11ms/step - loss: 0.0022 - root_mean_squared_error: 0.0470 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0828
# Epoch 92/150
# 664/664 [==============================] - 8s 11ms/step - loss: 0.0029 - root_mean_squared_error: 0.0535 - val_loss: 0.0068 - val_root_mean_squared_error: 0.0823
# Epoch 93/150
# 664/664 [==============================] - 7s 11ms/step - loss: 0.0023 - root_mean_squared_error: 0.0482 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0786
# Epoch 94/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0022 - root_mean_squared_error: 0.0470 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0773
# Epoch 95/150
# 664/664 [==============================] - 8s 11ms/step - loss: 0.0024 - root_mean_squared_error: 0.0485 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0828
# Epoch 96/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0026 - root_mean_squared_error: 0.0513 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0787
# Epoch 97/150
# 664/664 [==============================] - 8s 11ms/step - loss: 0.0023 - root_mean_squared_error: 0.0485 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0816
# Epoch 98/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0021 - root_mean_squared_error: 0.0458 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0791
# Epoch 99/150
# 664/664 [==============================] - 9s 13ms/step - loss: 0.0023 - root_mean_squared_error: 0.0475 - val_loss: 0.0068 - val_root_mean_squared_error: 0.0824
# Epoch 100/150
# 664/664 [==============================] - 9s 13ms/step - loss: 0.0021 - root_mean_squared_error: 0.0461 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0817
# Epoch 101/150
# 664/664 [==============================] - 9s 13ms/step - loss: 0.0028 - root_mean_squared_error: 0.0520 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0794
# Epoch 102/150
# 664/664 [==============================] - 9s 14ms/step - loss: 0.0022 - root_mean_squared_error: 0.0473 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0798
# Epoch 103/150
# 664/664 [==============================] - 9s 14ms/step - loss: 0.0028 - root_mean_squared_error: 0.0533 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0756
# Epoch 104/150
# 664/664 [==============================] - 9s 14ms/step - loss: 0.0026 - root_mean_squared_error: 0.0510 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0791
# Epoch 105/150
# 664/664 [==============================] - 9s 13ms/step - loss: 0.0024 - root_mean_squared_error: 0.0485 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0800
# Epoch 106/150
# 664/664 [==============================] - 9s 13ms/step - loss: 0.0021 - root_mean_squared_error: 0.0454 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0820
# Epoch 107/150
# 664/664 [==============================] - 8s 13ms/step - loss: 0.0026 - root_mean_squared_error: 0.0513 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0808
# Epoch 108/150
# 664/664 [==============================] - 9s 13ms/step - loss: 0.0022 - root_mean_squared_error: 0.0472 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0805
# Epoch 109/150
# 664/664 [==============================] - 8s 13ms/step - loss: 0.0022 - root_mean_squared_error: 0.0473 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0785
# Epoch 110/150
# 664/664 [==============================] - 9s 13ms/step - loss: 0.0021 - root_mean_squared_error: 0.0463 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0820
# Epoch 111/150
# 664/664 [==============================] - 8s 13ms/step - loss: 0.0021 - root_mean_squared_error: 0.0462 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0787
# Epoch 112/150
# 664/664 [==============================] - 10s 15ms/step - loss: 0.0021 - root_mean_squared_error: 0.0455 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0804
# Epoch 113/150
# 664/664 [==============================] - 9s 14ms/step - loss: 0.0024 - root_mean_squared_error: 0.0486 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0801
# Epoch 114/150
# 664/664 [==============================] - 9s 14ms/step - loss: 0.0022 - root_mean_squared_error: 0.0470 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0816
# Epoch 115/150
# 664/664 [==============================] - 8s 13ms/step - loss: 0.0029 - root_mean_squared_error: 0.0539 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0869
# Epoch 116/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0023 - root_mean_squared_error: 0.0479 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0803
# Epoch 117/150
# 664/664 [==============================] - 8s 13ms/step - loss: 0.0024 - root_mean_squared_error: 0.0485 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0832
# Epoch 118/150
# 664/664 [==============================] - 8s 13ms/step - loss: 0.0022 - root_mean_squared_error: 0.0469 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0821
# Epoch 119/150
# 664/664 [==============================] - 8s 13ms/step - loss: 0.0021 - root_mean_squared_error: 0.0455 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0780
# Epoch 120/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0024 - root_mean_squared_error: 0.0494 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0806
# Epoch 121/150
# 664/664 [==============================] - 9s 13ms/step - loss: 0.0021 - root_mean_squared_error: 0.0460 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0839
# Epoch 122/150
# 664/664 [==============================] - 9s 13ms/step - loss: 0.0027 - root_mean_squared_error: 0.0518 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0815
# Epoch 123/150
# 664/664 [==============================] - 9s 13ms/step - loss: 0.0020 - root_mean_squared_error: 0.0445 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0829
# Epoch 124/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0020 - root_mean_squared_error: 0.0445 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0797
# Epoch 125/150
# 664/664 [==============================] - 8s 13ms/step - loss: 0.0023 - root_mean_squared_error: 0.0484 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0815
# Epoch 126/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0019 - root_mean_squared_error: 0.0437 - val_loss: 0.0068 - val_root_mean_squared_error: 0.0826
# Epoch 127/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0023 - root_mean_squared_error: 0.0477 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0771
# Epoch 128/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0021 - root_mean_squared_error: 0.0456 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0799
# Epoch 129/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0021 - root_mean_squared_error: 0.0456 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0804
# Epoch 130/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0023 - root_mean_squared_error: 0.0477 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0815
# Epoch 131/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0021 - root_mean_squared_error: 0.0456 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0777
# Epoch 132/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0023 - root_mean_squared_error: 0.0484 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0787
# Epoch 133/150
# 664/664 [==============================] - 9s 13ms/step - loss: 0.0020 - root_mean_squared_error: 0.0447 - val_loss: 0.0068 - val_root_mean_squared_error: 0.0826
# Epoch 134/150
# 664/664 [==============================] - 8s 13ms/step - loss: 0.0020 - root_mean_squared_error: 0.0448 - val_loss: 0.0068 - val_root_mean_squared_error: 0.0824
# Epoch 135/150
# 664/664 [==============================] - 9s 13ms/step - loss: 0.0022 - root_mean_squared_error: 0.0468 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0811
# Epoch 136/150
# 664/664 [==============================] - 9s 13ms/step - loss: 0.0025 - root_mean_squared_error: 0.0498 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0789
# Epoch 137/150
# 664/664 [==============================] - 9s 13ms/step - loss: 0.0022 - root_mean_squared_error: 0.0470 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0795
# Epoch 138/150
# 664/664 [==============================] - 12s 18ms/step - loss: 0.0020 - root_mean_squared_error: 0.0451 - val_loss: 0.0068 - val_root_mean_squared_error: 0.0826
# Epoch 139/150
# 664/664 [==============================] - 10s 15ms/step - loss: 0.0021 - root_mean_squared_error: 0.0454 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0789
# Epoch 140/150
# 664/664 [==============================] - 9s 14ms/step - loss: 0.0022 - root_mean_squared_error: 0.0468 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0767
# Epoch 141/150
# 664/664 [==============================] - 8s 12ms/step - loss: 0.0018 - root_mean_squared_error: 0.0429 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0807
# Epoch 142/150
# 664/664 [==============================] - 8s 13ms/step - loss: 0.0025 - root_mean_squared_error: 0.0502 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0780
# Epoch 143/150
# 664/664 [==============================] - 9s 13ms/step - loss: 0.0021 - root_mean_squared_error: 0.0454 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0775
# Epoch 144/150
# 664/664 [==============================] - 9s 13ms/step - loss: 0.0019 - root_mean_squared_error: 0.0440 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0794
# Epoch 145/150
# 664/664 [==============================] - 8s 13ms/step - loss: 0.0021 - root_mean_squared_error: 0.0453 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0833
# Epoch 146/150
# 664/664 [==============================] - 9s 13ms/step - loss: 0.0019 - root_mean_squared_error: 0.0436 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0787
# Epoch 147/150
# 664/664 [==============================] - 9s 13ms/step - loss: 0.0022 - root_mean_squared_error: 0.0465 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0790
# Epoch 148/150
# 664/664 [==============================] - 11s 17ms/step - loss: 0.0020 - root_mean_squared_error: 0.0442 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0795
# Epoch 149/150
# 664/664 [==============================] - 10s 14ms/step - loss: 0.0020 - root_mean_squared_error: 0.0452 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0813
# Epoch 150/150
# 664/664 [==============================] - 9s 14ms/step - loss: 0.0022 - root_mean_squared_error: 0.0464 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0839
# INFO:tensorflow:Assets written to: ./gdrive/My Drive/data/CSC/W4/W4662FM0605_encoded/assets

# %%
if retrain:
    fig, ax = plt.subplots(figsize=(10,5))

    ax.plot(lstm_ae_model.history['loss'], marker='.', label='loss')
    ax.plot(lstm_ae_model.history['val_loss'], marker='.', label='validation loss')

    ax.legend()
    ax.grid(True)

    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.savefig('epoches.png', dpi=300)
    plt.show()

# %%
synthetic_pd = pd.DataFrame.from_records([i[0] for i in synthetic_data])

# %% [markdown]
# # Validation

# %% [markdown]
# ## PCA

# %%
from sklearn.decomposition import PCA

pca_scale = PCA(n_components=2)
pca_scale = pca_scale.fit(X_source)

X_source_dr = pca_scale.transform(X_source)
x_min, x_max = X_source_dr.min(0), X_source_dr.max(0)
X_norm = (X_source_dr-x_min) / (x_max-x_min)  #Normalize
X_source_df = pd.DataFrame(X_norm, columns = ['dim1','dim2'])

X_target_dr = pca_scale.transform(X_target)
x_min, x_max = X_target_dr.min(0), X_target_dr.max(0)
X_norm = (X_target_dr-x_min) / (x_max-x_min)  #Normalize
X_target_df = pd.DataFrame(X_norm, columns = ['dim1','dim2'])

X_decoder_dr = pca_scale.transform(synthetic_pd)
x_min, x_max = X_decoder_dr.min(0), X_decoder_dr.max(0)
X_norm = (X_decoder_dr-x_min) / (x_max-x_min)  #Normalize
X_decode_df = pd.DataFrame(X_norm, columns = ['dim1','dim2'])

# %%
fig, ax = plt.subplots(figsize=(10,5))

ax.scatter(X_source_df['dim1'], X_source_df['dim2'], alpha=0.1, label='source')
ax.scatter(X_target_df['dim1'], X_target_df['dim2'], alpha=0.1, label='target')
ax.scatter(X_decode_df['dim1'], X_decode_df['dim2'], alpha=0.1, label='synthetic')

ax.legend()
ax.grid(True)

#plt.ylim(0, 1)
#plt.xlim(0, 1)
plt.savefig('distribution.png', dpi=300)
plt.show()

# %% [markdown]
# ## Model Cross Validation

# %%
model_source = svm.OneClassSVM(nu=0.01, kernel="rbf", gamma=0.01).fit(X_source)
model_target = svm.OneClassSVM(nu=0.01, kernel="rbf", gamma=0.01).fit(X_target)
model_synthetic = svm.OneClassSVM(nu=0.01, kernel="rbf", gamma=0.01).fit(synthetic_pd)

# %%
def scorer_(Y_pred):
    a = (Y_pred[Y_pred == -1].size)/(Y_pred.size)
    return a*100

# %%
def plot_score (score_list, date_list, tag):

    fig, ax = plt.subplots(figsize=(10, 3))
    plt.xticks(rotation=45)
    ax.plot(date_list, score_list, '.-')
    ax.set(xlabel='date', ylabel='score', title=tag)
    ax.grid()
    plt.ylim(0, 100)
    plt.tight_layout()
    #fig.savefig(path+tag+'-'+training_from.strftime("%Y%m%d")+'-'+training_to.strftime("%Y%m%d")+'.png', dpi=300)
    plt.show()

# %%
def get_score (data_df, start_date, end_date, normalizer, prediction_model):

    score_list = []
    date_list = []
    delta = datetime.timedelta(days=1)

    while start_date <= end_date:

        validation_df = data_df[(data_df['datetime'] > start_date) & 
                                (data_df['datetime'] <= start_date + delta)]

        
        if len(validation_df) > 0:

            validation_df_score = validation_df.drop(columns=drop_list)
            validation_df_score = normalizer.transform(validation_df_score)
            validation_df_score = prediction_model.predict(validation_df_score)

            score_list.append(scorer_(validation_df_score))
            date_list.append(start_date)

        start_date += delta
        
    return score_list, date_list

# %%
target_score_cv, target_date_cv = get_score(globals()[tag_dict['target']], 
                                            tag_dict['target_training_from'], 
                                            tag_dict['target_end'], 
                                            normalizer,
                                            model_source)

target_score, target_date = get_score(globals()[tag_dict['target']], 
                                            tag_dict['target_training_from'], 
                                            tag_dict['target_end'], 
                                            normalizer,
                                            model_target)

target_score_da, target_date_da = get_score(globals()[tag_dict['target']], 
                                            tag_dict['target_training_from'], 
                                            tag_dict['target_end'], 
                                            normalizer,
                                            model_synthetic)

# %%
def rmse(predictions, targets):
    return np.sqrt(((predictions - targets) ** 2).mean())

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(target_score_cv, target_score, squared=False)
# Out:
# 31.339174861983587

# %%
da_rmse = mean_squared_error(target_score_da, target_score, squared=False)
cv_rmse = mean_squared_error(target_score_cv, target_score, squared=False)



plot_score (target_score, target_date, 'Detect ' + tag_dict['target'] +' conditions by using '+ tag_dict['target'] +' model')

plot_score (target_score_cv, 
            target_date_cv, 
            'Detect ' + tag_dict['target'] +' conditions by using '+ tag_dict['source'] +' model, RMSE='+ "{:.3f}".format(cv_rmse))

plot_score (target_score_da, 
            target_date_da, 
            'Detect ' + tag_dict['target'] +' conditions by using '+ tag_dict['source'] +' synthetic model, RMSE=' + "{:.3f}".format(da_rmse))

# %% [markdown]
# ## Check Synthetic Data

# %%
feature_index = 206
duration = 26000
interval = 100
fig, ax = plt.subplots(figsize=(10,5))

ax.plot(range(duration, duration+interval), X_target[feature_index].head(duration).tail(interval), label='target', marker='.')
ax.plot(range(duration, duration+interval), X_source[feature_index].head(duration).tail(interval), label='source', marker='.')
ax.plot(range(duration, duration+interval), synthetic_pd[feature_index].head(duration).tail(interval), label='synthetic', marker='.')

ax.legend()
ax.grid(True)
plt.tight_layout()

#plt.savefig('distribution.png', dpi=300)
plt.show()
