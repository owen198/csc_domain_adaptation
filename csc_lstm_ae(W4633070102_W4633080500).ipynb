# %% [markdown]
# <a href="https://colab.research.google.com/github/owen198/csc_domain_adaptation/blob/main/csc_lstm_ae(W4633070102_W4633080500).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# https://towardsdatascience.com/step-by-step-understanding-lstm-autoencoder-layers-ffab055b6352

from sklearn import preprocessing
from sklearn import svm
import pandas as pd
import datetime

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import random


from keras import metrics
from keras import models
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from keras.layers import Input, BatchNormalization, Activation
from keras.callbacks import EarlyStopping

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# # Load Data and proprecessing

# %%
tag_dict = {'source':'W4633070102',
            'source_training_from': datetime.datetime(2018,9,1,0,0),
            'source_training_to': datetime.datetime(2018,12,1,0,0),
            'source_end': datetime.datetime(2019,3,1,0,0),
            
            'target':'W4633080500',
            'target_training_from': datetime.datetime(2018,9,1,0,0),
            'target_training_to': datetime.datetime(2018,12,1,0,0),
            'target_end': datetime.datetime(2019,3,1,0,0)}

path = './gdrive/MyDrive/data/CSC/W4/'

# %%
globals()[tag_dict['target']] = pd.concat([pd.read_csv(path + tag_dict['target'] + '_201809.csv'),
                                          pd.read_csv(path + tag_dict['target'] + '_201810.csv'),
                                          pd.read_csv(path + tag_dict['target'] + '_201811.csv'),
                                          pd.read_csv(path + tag_dict['target'] + '_201812.csv'),
                                          pd.read_csv(path + tag_dict['target'] + '_201901.csv'),
                                          pd.read_csv(path + tag_dict['target'] + '_201902.csv'),
                                          pd.read_csv(path + tag_dict['target'] + '_201903.csv')])

globals()[tag_dict['source']] = pd.concat([pd.read_csv(path + tag_dict['source'] + '_201809.csv'),
                                          pd.read_csv(path + tag_dict['source'] + '_201810.csv'),
                                          pd.read_csv(path + tag_dict['source'] + '_201811.csv'),
                                          pd.read_csv(path + tag_dict['source'] + '_201812.csv'),
                                          pd.read_csv(path + tag_dict['source'] + '_201901.csv'),
                                          pd.read_csv(path + tag_dict['source'] + '_201902.csv'),
                                          pd.read_csv(path + tag_dict['source'] + '_201903.csv')])

# %%
globals()[tag_dict['source']]['datetime'] = globals()[tag_dict['source']]['timestamp'].astype('int').astype("datetime64[s]")
globals()[tag_dict['target']]['datetime'] = globals()[tag_dict['target']]['timestamp'].astype('int').astype("datetime64[s]")

# %%
globals()[tag_dict['source']+'_training'] = globals()[tag_dict['source']][
                                                  (globals()[tag_dict['source']]['datetime'] > tag_dict['source_training_from']) &
                                                  (globals()[tag_dict['source']]['datetime'] <= tag_dict['source_training_to']) ]

globals()[tag_dict['target']+'_training'] = globals()[tag_dict['target']][
                                                  (globals()[tag_dict['target']]['datetime'] > tag_dict['target_training_from']) &
                                                  (globals()[tag_dict['target']]['datetime'] <= tag_dict['target_training_to']) ]

# %%
drop_list = ['Unnamed: 0', '_id','type','scada','timestamp','device', 'datetime']

globals()[tag_dict['source']+'_training'] = globals()[tag_dict['source']+'_training'].drop(columns=drop_list)
globals()[tag_dict['target']+'_training'] = globals()[tag_dict['target']+'_training'].drop(columns=drop_list)

# %%
shape_min = min (globals()[tag_dict['source']+'_training'].shape[0], 
                 globals()[tag_dict['target']+'_training'].shape[0])
shape_max = max (globals()[tag_dict['source']+'_training'].shape[0], 
                 globals()[tag_dict['target']+'_training'].shape[0])

index = sorted(random.sample(range(0, shape_max), shape_min))

# %%
normalizer = preprocessing.MinMaxScaler()
normalizer = normalizer.fit(globals()[tag_dict['source']+'_training'])

X_source = pd.DataFrame(normalizer.transform(globals()[tag_dict['source']+'_training']))
X_target = pd.DataFrame(normalizer.transform(globals()[tag_dict['target']+'_training']))

# %%
def temporalize(X, y, lookback):
    output_X = []
    output_y = []
    for i in range(len(X)-lookback-1):
        t = []
        for j in range(1,lookback+1):
            # Gather past records upto the lookback period
            t.append(X[[(i+j+1)], :])
        output_X.append(t)
        output_y.append(y[i+lookback+1])
    return output_X, output_y

# %%
if len(X_target) > len(X_source):
    X = X_target.iloc[index]
    Y = X_source
else:
    X = X_target
    Y = X_source.iloc[index]


timesteps = 4
n_features = 390

#X, y = temporalize(X = timeseries, y = np.zeros(len(timeseries)), lookback = timesteps)
X, _ = temporalize(X = X.values, y = np.zeros(len(X)), lookback = timesteps)
Y, _ = temporalize(X = Y.values, y = np.zeros(len(Y)), lookback = timesteps)

X = np.array(X)
X = X.reshape(X.shape[0], timesteps, n_features)

Y = np.array(Y)
Y = Y.reshape(np.array(Y).shape[0], timesteps, n_features)

# %% [markdown]
# # LSTM-AE Model

# %%
def lstm_ae():
    # define model
    model = Sequential()
    model.add(LSTM(64, activation='relu', input_shape=(timesteps,n_features), return_sequences=True))
    model.add(LSTM(16, activation='relu', return_sequences=False))
    model.add(RepeatVector(timesteps))
    model.add(LSTM(16, activation='relu', return_sequences=True))
    model.add(LSTM(64, activation='relu', return_sequences=True))
    model.add(TimeDistributed(Dense(n_features)))
    model.compile(optimizer='adam', loss='mse', metrics=[metrics.RootMeanSquaredError()])
    model.summary()

    return model

# %%
model_name = './gdrive/My Drive/data/CSC/W4/' + tag_dict['target'] + '_encoded'
model_name
# Out:
# './gdrive/My Drive/data/CSC/W4/W4633080500_encoded'

# %%
retrain = True


if retrain:
    early_stopping = EarlyStopping(monitor='val_loss', patience=150, verbose=2)

    model = lstm_ae ()
    lstm_ae_model = model.fit(Y, X, epochs=150, batch_size=16, verbose=1, validation_split=0.2, callbacks=[early_stopping])
    model.save(model_name)
else:
    model = models.load_model(model_name)  
    

#model = models.load_model(model_name)    
synthetic_data = model.predict(X, verbose=0)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 4, 64)             116480
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 16)                5184
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 4, 16)             0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 4, 16)             2112
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 4, 64)             20736
# _________________________________________________________________
# time_distributed (TimeDistri (None, 4, 390)            25350
# =================================================================
# Total params: 169,862
# Trainable params: 169,862
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/150
# 673/673 [==============================] - 12s 12ms/step - loss: 0.2061 - root_mean_squared_error: 0.4241 - val_loss: 0.0305 - val_root_mean_squared_error: 0.1747
# Epoch 2/150
# 673/673 [==============================] - 7s 11ms/step - loss: 0.0314 - root_mean_squared_error: 0.1771 - val_loss: 0.0202 - val_root_mean_squared_error: 0.1420
# Epoch 3/150
# 673/673 [==============================] - 7s 11ms/step - loss: 0.0306 - root_mean_squared_error: 0.1749 - val_loss: 0.0183 - val_root_mean_squared_error: 0.1353
# Epoch 4/150
# 673/673 [==============================] - 7s 11ms/step - loss: 0.0301 - root_mean_squared_error: 0.1736 - val_loss: 0.0199 - val_root_mean_squared_error: 0.1410
# Epoch 5/150
# 673/673 [==============================] - 7s 11ms/step - loss: 0.0297 - root_mean_squared_error: 0.1722 - val_loss: 0.0256 - val_root_mean_squared_error: 0.1600
# Epoch 6/150
# 673/673 [==============================] - 7s 11ms/step - loss: 0.0293 - root_mean_squared_error: 0.1713 - val_loss: 0.0211 - val_root_mean_squared_error: 0.1451
# Epoch 7/150
# 673/673 [==============================] - 7s 11ms/step - loss: 0.0290 - root_mean_squared_error: 0.1704 - val_loss: 0.0211 - val_root_mean_squared_error: 0.1451
# Epoch 8/150
# 673/673 [==============================] - 7s 11ms/step - loss: 0.0287 - root_mean_squared_error: 0.1695 - val_loss: 0.0192 - val_root_mean_squared_error: 0.1387
# Epoch 9/150
# 673/673 [==============================] - 7s 11ms/step - loss: 0.0286 - root_mean_squared_error: 0.1692 - val_loss: 0.0189 - val_root_mean_squared_error: 0.1376
# Epoch 10/150
# 673/673 [==============================] - 7s 11ms/step - loss: 0.0282 - root_mean_squared_error: 0.1680 - val_loss: 0.0227 - val_root_mean_squared_error: 0.1505
# Epoch 11/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0275 - root_mean_squared_error: 0.1658 - val_loss: 0.0193 - val_root_mean_squared_error: 0.1391
# Epoch 12/150
# 673/673 [==============================] - 7s 11ms/step - loss: 0.0274 - root_mean_squared_error: 0.1656 - val_loss: 0.0201 - val_root_mean_squared_error: 0.1419
# Epoch 13/150
# 673/673 [==============================] - 7s 11ms/step - loss: 0.0278 - root_mean_squared_error: 0.1668 - val_loss: 0.0203 - val_root_mean_squared_error: 0.1426
# Epoch 14/150
# 673/673 [==============================] - 7s 11ms/step - loss: 0.0272 - root_mean_squared_error: 0.1650 - val_loss: 0.0224 - val_root_mean_squared_error: 0.1498
# Epoch 15/150
# 673/673 [==============================] - 7s 11ms/step - loss: 0.0265 - root_mean_squared_error: 0.1627 - val_loss: 0.0205 - val_root_mean_squared_error: 0.1433
# Epoch 16/150
# 673/673 [==============================] - 7s 11ms/step - loss: 0.0264 - root_mean_squared_error: 0.1624 - val_loss: 0.0202 - val_root_mean_squared_error: 0.1421
# Epoch 17/150
# 673/673 [==============================] - 7s 11ms/step - loss: 0.0255 - root_mean_squared_error: 0.1596 - val_loss: 0.0222 - val_root_mean_squared_error: 0.1488
# Epoch 18/150
# 673/673 [==============================] - 7s 11ms/step - loss: 0.0254 - root_mean_squared_error: 0.1593 - val_loss: 0.0225 - val_root_mean_squared_error: 0.1501
# Epoch 19/150
# 673/673 [==============================] - 7s 11ms/step - loss: 0.0250 - root_mean_squared_error: 0.1583 - val_loss: 0.0206 - val_root_mean_squared_error: 0.1435
# Epoch 20/150
# 673/673 [==============================] - 7s 11ms/step - loss: 0.0250 - root_mean_squared_error: 0.1580 - val_loss: 0.0197 - val_root_mean_squared_error: 0.1402
# Epoch 21/150
# 673/673 [==============================] - 7s 11ms/step - loss: 0.0240 - root_mean_squared_error: 0.1548 - val_loss: 0.0208 - val_root_mean_squared_error: 0.1443
# Epoch 22/150
# 673/673 [==============================] - 7s 11ms/step - loss: 0.0245 - root_mean_squared_error: 0.1564 - val_loss: 0.0186 - val_root_mean_squared_error: 0.1364
# Epoch 23/150
# 673/673 [==============================] - 7s 11ms/step - loss: 0.0239 - root_mean_squared_error: 0.1546 - val_loss: 0.0222 - val_root_mean_squared_error: 0.1489
# Epoch 24/150
# 673/673 [==============================] - 7s 11ms/step - loss: 0.0236 - root_mean_squared_error: 0.1537 - val_loss: 0.0195 - val_root_mean_squared_error: 0.1396
# Epoch 25/150
# 673/673 [==============================] - 7s 11ms/step - loss: 0.0236 - root_mean_squared_error: 0.1537 - val_loss: 0.0207 - val_root_mean_squared_error: 0.1438
# Epoch 26/150
# 673/673 [==============================] - 7s 11ms/step - loss: 0.0233 - root_mean_squared_error: 0.1525 - val_loss: 0.0212 - val_root_mean_squared_error: 0.1456
# Epoch 27/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0223 - root_mean_squared_error: 0.1493 - val_loss: 0.0218 - val_root_mean_squared_error: 0.1476
# Epoch 28/150
# 673/673 [==============================] - 7s 11ms/step - loss: 0.0222 - root_mean_squared_error: 0.1491 - val_loss: 0.0190 - val_root_mean_squared_error: 0.1377
# Epoch 29/150
# 673/673 [==============================] - 7s 11ms/step - loss: 0.0220 - root_mean_squared_error: 0.1482 - val_loss: 0.0190 - val_root_mean_squared_error: 0.1377
# Epoch 30/150
# 673/673 [==============================] - 7s 11ms/step - loss: 0.0216 - root_mean_squared_error: 0.1469 - val_loss: 0.0258 - val_root_mean_squared_error: 0.1605
# Epoch 31/150
# 673/673 [==============================] - 7s 11ms/step - loss: 0.0207 - root_mean_squared_error: 0.1439 - val_loss: 0.0258 - val_root_mean_squared_error: 0.1606
# Epoch 32/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0207 - root_mean_squared_error: 0.1440 - val_loss: 0.0213 - val_root_mean_squared_error: 0.1458
# Epoch 33/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0209 - root_mean_squared_error: 0.1447 - val_loss: 0.0222 - val_root_mean_squared_error: 0.1491
# Epoch 34/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0206 - root_mean_squared_error: 0.1435 - val_loss: 0.0243 - val_root_mean_squared_error: 0.1558
# Epoch 35/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0205 - root_mean_squared_error: 0.1433 - val_loss: 0.0255 - val_root_mean_squared_error: 0.1597
# Epoch 36/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0200 - root_mean_squared_error: 0.1414 - val_loss: 0.0208 - val_root_mean_squared_error: 0.1441
# Epoch 37/150
# 673/673 [==============================] - 7s 11ms/step - loss: 0.0198 - root_mean_squared_error: 0.1406 - val_loss: 0.0228 - val_root_mean_squared_error: 0.1510
# Epoch 38/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0196 - root_mean_squared_error: 0.1399 - val_loss: 0.0208 - val_root_mean_squared_error: 0.1441
# Epoch 39/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0194 - root_mean_squared_error: 0.1394 - val_loss: 0.0245 - val_root_mean_squared_error: 0.1567
# Epoch 40/150
# 673/673 [==============================] - 7s 11ms/step - loss: 0.0195 - root_mean_squared_error: 0.1395 - val_loss: 0.0237 - val_root_mean_squared_error: 0.1539
# Epoch 41/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0191 - root_mean_squared_error: 0.1381 - val_loss: 0.0205 - val_root_mean_squared_error: 0.1432
# Epoch 42/150
# 673/673 [==============================] - 7s 11ms/step - loss: 0.0191 - root_mean_squared_error: 0.1380 - val_loss: 0.0219 - val_root_mean_squared_error: 0.1481
# Epoch 43/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0191 - root_mean_squared_error: 0.1383 - val_loss: 0.0235 - val_root_mean_squared_error: 0.1532
# Epoch 44/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0189 - root_mean_squared_error: 0.1374 - val_loss: 0.0234 - val_root_mean_squared_error: 0.1530
# Epoch 45/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0181 - root_mean_squared_error: 0.1347 - val_loss: 0.0224 - val_root_mean_squared_error: 0.1498
# Epoch 46/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0182 - root_mean_squared_error: 0.1349 - val_loss: 0.0216 - val_root_mean_squared_error: 0.1470
# Epoch 47/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0183 - root_mean_squared_error: 0.1352 - val_loss: 0.0235 - val_root_mean_squared_error: 0.1534
# Epoch 48/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0185 - root_mean_squared_error: 0.1359 - val_loss: 0.0253 - val_root_mean_squared_error: 0.1592
# Epoch 49/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0179 - root_mean_squared_error: 0.1336 - val_loss: 0.0291 - val_root_mean_squared_error: 0.1707
# Epoch 50/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0184 - root_mean_squared_error: 0.1355 - val_loss: 0.0237 - val_root_mean_squared_error: 0.1540
# Epoch 51/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0173 - root_mean_squared_error: 0.1315 - val_loss: 0.0241 - val_root_mean_squared_error: 0.1553
# Epoch 52/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0173 - root_mean_squared_error: 0.1317 - val_loss: 0.0259 - val_root_mean_squared_error: 0.1608
# Epoch 53/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0173 - root_mean_squared_error: 0.1316 - val_loss: 0.0216 - val_root_mean_squared_error: 0.1471
# Epoch 54/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0172 - root_mean_squared_error: 0.1311 - val_loss: 0.0227 - val_root_mean_squared_error: 0.1506
# Epoch 55/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0167 - root_mean_squared_error: 0.1293 - val_loss: 0.0238 - val_root_mean_squared_error: 0.1544
# Epoch 56/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0167 - root_mean_squared_error: 0.1291 - val_loss: 0.0239 - val_root_mean_squared_error: 0.1546
# Epoch 57/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0170 - root_mean_squared_error: 0.1303 - val_loss: 0.0248 - val_root_mean_squared_error: 0.1575
# Epoch 58/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0169 - root_mean_squared_error: 0.1301 - val_loss: 0.0238 - val_root_mean_squared_error: 0.1542
# Epoch 59/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0160 - root_mean_squared_error: 0.1263 - val_loss: 0.0258 - val_root_mean_squared_error: 0.1606
# Epoch 60/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0159 - root_mean_squared_error: 0.1259 - val_loss: 0.0250 - val_root_mean_squared_error: 0.1580
# Epoch 61/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0164 - root_mean_squared_error: 0.1280 - val_loss: 0.0281 - val_root_mean_squared_error: 0.1677
# Epoch 62/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0161 - root_mean_squared_error: 0.1267 - val_loss: 0.0275 - val_root_mean_squared_error: 0.1658
# Epoch 63/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0160 - root_mean_squared_error: 0.1266 - val_loss: 0.0248 - val_root_mean_squared_error: 0.1576
# Epoch 64/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0160 - root_mean_squared_error: 0.1265 - val_loss: 0.0257 - val_root_mean_squared_error: 0.1604
# Epoch 65/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0158 - root_mean_squared_error: 0.1256 - val_loss: 0.0252 - val_root_mean_squared_error: 0.1588
# Epoch 66/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0157 - root_mean_squared_error: 0.1255 - val_loss: 0.0249 - val_root_mean_squared_error: 0.1578
# Epoch 67/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0157 - root_mean_squared_error: 0.1252 - val_loss: 0.0236 - val_root_mean_squared_error: 0.1537
# Epoch 68/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0156 - root_mean_squared_error: 0.1247 - val_loss: 0.0245 - val_root_mean_squared_error: 0.1566
# Epoch 69/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0151 - root_mean_squared_error: 0.1229 - val_loss: 0.0257 - val_root_mean_squared_error: 0.1604
# Epoch 70/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0152 - root_mean_squared_error: 0.1232 - val_loss: 0.0250 - val_root_mean_squared_error: 0.1580
# Epoch 71/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0153 - root_mean_squared_error: 0.1238 - val_loss: 0.0242 - val_root_mean_squared_error: 0.1557
# Epoch 72/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0154 - root_mean_squared_error: 0.1242 - val_loss: 0.0249 - val_root_mean_squared_error: 0.1578
# Epoch 73/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0150 - root_mean_squared_error: 0.1223 - val_loss: 0.0257 - val_root_mean_squared_error: 0.1602
# Epoch 74/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0147 - root_mean_squared_error: 0.1213 - val_loss: 0.0249 - val_root_mean_squared_error: 0.1578
# Epoch 75/150
# 673/673 [==============================] - 8s 12ms/step - loss: 0.0152 - root_mean_squared_error: 0.1233 - val_loss: 0.0242 - val_root_mean_squared_error: 0.1557
# Epoch 76/150
# 673/673 [==============================] - 8s 12ms/step - loss: 0.0147 - root_mean_squared_error: 0.1211 - val_loss: 0.0234 - val_root_mean_squared_error: 0.1531
# Epoch 77/150
# 673/673 [==============================] - 8s 12ms/step - loss: 0.0147 - root_mean_squared_error: 0.1213 - val_loss: 0.0229 - val_root_mean_squared_error: 0.1512
# Epoch 78/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0146 - root_mean_squared_error: 0.1208 - val_loss: 0.0251 - val_root_mean_squared_error: 0.1585
# Epoch 79/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0145 - root_mean_squared_error: 0.1206 - val_loss: 0.0256 - val_root_mean_squared_error: 0.1601
# Epoch 80/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0144 - root_mean_squared_error: 0.1202 - val_loss: 0.0254 - val_root_mean_squared_error: 0.1593
# Epoch 81/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0144 - root_mean_squared_error: 0.1201 - val_loss: 0.0245 - val_root_mean_squared_error: 0.1565
# Epoch 82/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0142 - root_mean_squared_error: 0.1192 - val_loss: 0.0253 - val_root_mean_squared_error: 0.1592
# Epoch 83/150
# 673/673 [==============================] - 8s 12ms/step - loss: 0.0140 - root_mean_squared_error: 0.1185 - val_loss: 0.0266 - val_root_mean_squared_error: 0.1630
# Epoch 84/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0146 - root_mean_squared_error: 0.1207 - val_loss: 0.0248 - val_root_mean_squared_error: 0.1575
# Epoch 85/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0141 - root_mean_squared_error: 0.1189 - val_loss: 0.0268 - val_root_mean_squared_error: 0.1638
# Epoch 86/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0139 - root_mean_squared_error: 0.1179 - val_loss: 0.0263 - val_root_mean_squared_error: 0.1622
# Epoch 87/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0139 - root_mean_squared_error: 0.1180 - val_loss: 0.0260 - val_root_mean_squared_error: 0.1612
# Epoch 88/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0139 - root_mean_squared_error: 0.1181 - val_loss: 0.0263 - val_root_mean_squared_error: 0.1623
# Epoch 89/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0131 - root_mean_squared_error: 0.1143 - val_loss: 0.0261 - val_root_mean_squared_error: 0.1617
# Epoch 90/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0138 - root_mean_squared_error: 0.1177 - val_loss: 0.0245 - val_root_mean_squared_error: 0.1566
# Epoch 91/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0137 - root_mean_squared_error: 0.1169 - val_loss: 0.0271 - val_root_mean_squared_error: 0.1647
# Epoch 92/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0138 - root_mean_squared_error: 0.1174 - val_loss: 0.0237 - val_root_mean_squared_error: 0.1540
# Epoch 93/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0134 - root_mean_squared_error: 0.1157 - val_loss: 0.0249 - val_root_mean_squared_error: 0.1578
# Epoch 94/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0135 - root_mean_squared_error: 0.1161 - val_loss: 0.0257 - val_root_mean_squared_error: 0.1603
# Epoch 95/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0134 - root_mean_squared_error: 0.1158 - val_loss: 0.0265 - val_root_mean_squared_error: 0.1629
# Epoch 96/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0134 - root_mean_squared_error: 0.1156 - val_loss: 0.0267 - val_root_mean_squared_error: 0.1634
# Epoch 97/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0130 - root_mean_squared_error: 0.1138 - val_loss: 0.0273 - val_root_mean_squared_error: 0.1653
# Epoch 98/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0133 - root_mean_squared_error: 0.1153 - val_loss: 0.0270 - val_root_mean_squared_error: 0.1642
# Epoch 99/150
# 673/673 [==============================] - 7s 11ms/step - loss: 0.0135 - root_mean_squared_error: 0.1160 - val_loss: 0.0269 - val_root_mean_squared_error: 0.1641
# Epoch 100/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0134 - root_mean_squared_error: 0.1158 - val_loss: 0.0257 - val_root_mean_squared_error: 0.1602
# Epoch 101/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0127 - root_mean_squared_error: 0.1125 - val_loss: 0.0265 - val_root_mean_squared_error: 0.1628
# Epoch 102/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0132 - root_mean_squared_error: 0.1150 - val_loss: 0.0270 - val_root_mean_squared_error: 0.1642
# Epoch 103/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0126 - root_mean_squared_error: 0.1121 - val_loss: 0.0252 - val_root_mean_squared_error: 0.1589
# Epoch 104/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0126 - root_mean_squared_error: 0.1124 - val_loss: 0.0254 - val_root_mean_squared_error: 0.1595
# Epoch 105/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0127 - root_mean_squared_error: 0.1126 - val_loss: 0.0256 - val_root_mean_squared_error: 0.1601
# Epoch 106/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0128 - root_mean_squared_error: 0.1130 - val_loss: 0.0278 - val_root_mean_squared_error: 0.1667
# Epoch 107/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0126 - root_mean_squared_error: 0.1123 - val_loss: 0.0277 - val_root_mean_squared_error: 0.1666
# Epoch 108/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0129 - root_mean_squared_error: 0.1133 - val_loss: 0.0263 - val_root_mean_squared_error: 0.1621
# Epoch 109/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0128 - root_mean_squared_error: 0.1133 - val_loss: 0.0267 - val_root_mean_squared_error: 0.1634
# Epoch 110/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0125 - root_mean_squared_error: 0.1117 - val_loss: 0.0291 - val_root_mean_squared_error: 0.1705
# Epoch 111/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0129 - root_mean_squared_error: 0.1137 - val_loss: 0.0284 - val_root_mean_squared_error: 0.1686
# Epoch 112/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0127 - root_mean_squared_error: 0.1127 - val_loss: 0.0257 - val_root_mean_squared_error: 0.1602
# Epoch 113/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0124 - root_mean_squared_error: 0.1112 - val_loss: 0.0264 - val_root_mean_squared_error: 0.1625
# Epoch 114/150
# 673/673 [==============================] - 8s 12ms/step - loss: 0.0120 - root_mean_squared_error: 0.1094 - val_loss: 0.0258 - val_root_mean_squared_error: 0.1607
# Epoch 115/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0126 - root_mean_squared_error: 0.1121 - val_loss: 0.0265 - val_root_mean_squared_error: 0.1627
# Epoch 116/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0124 - root_mean_squared_error: 0.1113 - val_loss: 0.0271 - val_root_mean_squared_error: 0.1648
# Epoch 117/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0126 - root_mean_squared_error: 0.1123 - val_loss: 0.0273 - val_root_mean_squared_error: 0.1653
# Epoch 118/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0122 - root_mean_squared_error: 0.1104 - val_loss: 0.0282 - val_root_mean_squared_error: 0.1680
# Epoch 119/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0123 - root_mean_squared_error: 0.1111 - val_loss: 0.0266 - val_root_mean_squared_error: 0.1632
# Epoch 120/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0123 - root_mean_squared_error: 0.1108 - val_loss: 0.0274 - val_root_mean_squared_error: 0.1655
# Epoch 121/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0119 - root_mean_squared_error: 0.1092 - val_loss: 0.0265 - val_root_mean_squared_error: 0.1627
# Epoch 122/150
# 673/673 [==============================] - 8s 12ms/step - loss: 0.0120 - root_mean_squared_error: 0.1096 - val_loss: 0.0246 - val_root_mean_squared_error: 0.1570
# Epoch 123/150
# 673/673 [==============================] - 8s 12ms/step - loss: 0.0122 - root_mean_squared_error: 0.1102 - val_loss: 0.0269 - val_root_mean_squared_error: 0.1641
# Epoch 124/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0119 - root_mean_squared_error: 0.1091 - val_loss: 0.0274 - val_root_mean_squared_error: 0.1656
# Epoch 125/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0119 - root_mean_squared_error: 0.1090 - val_loss: 0.0270 - val_root_mean_squared_error: 0.1644
# Epoch 126/150
# 673/673 [==============================] - 8s 12ms/step - loss: 0.0126 - root_mean_squared_error: 0.1123 - val_loss: 0.0293 - val_root_mean_squared_error: 0.1711
# Epoch 127/150
# 673/673 [==============================] - 8s 12ms/step - loss: 0.0116 - root_mean_squared_error: 0.1075 - val_loss: 0.0263 - val_root_mean_squared_error: 0.1623
# Epoch 128/150
# 673/673 [==============================] - 8s 12ms/step - loss: 0.0121 - root_mean_squared_error: 0.1098 - val_loss: 0.0284 - val_root_mean_squared_error: 0.1685
# Epoch 129/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0119 - root_mean_squared_error: 0.1090 - val_loss: 0.0274 - val_root_mean_squared_error: 0.1656
# Epoch 130/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0116 - root_mean_squared_error: 0.1077 - val_loss: 0.0278 - val_root_mean_squared_error: 0.1667
# Epoch 131/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0120 - root_mean_squared_error: 0.1095 - val_loss: 0.0289 - val_root_mean_squared_error: 0.1701
# Epoch 132/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0114 - root_mean_squared_error: 0.1067 - val_loss: 0.0280 - val_root_mean_squared_error: 0.1672
# Epoch 133/150
# 673/673 [==============================] - 8s 12ms/step - loss: 0.0117 - root_mean_squared_error: 0.1083 - val_loss: 0.0273 - val_root_mean_squared_error: 0.1654
# Epoch 134/150
# 673/673 [==============================] - 8s 12ms/step - loss: 0.0118 - root_mean_squared_error: 0.1086 - val_loss: 0.0283 - val_root_mean_squared_error: 0.1682
# Epoch 135/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0117 - root_mean_squared_error: 0.1083 - val_loss: 0.0269 - val_root_mean_squared_error: 0.1641
# Epoch 136/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0116 - root_mean_squared_error: 0.1075 - val_loss: 0.0267 - val_root_mean_squared_error: 0.1636
# Epoch 137/150
# 673/673 [==============================] - 8s 12ms/step - loss: 0.0118 - root_mean_squared_error: 0.1086 - val_loss: 0.0273 - val_root_mean_squared_error: 0.1653
# Epoch 138/150
# 673/673 [==============================] - 8s 12ms/step - loss: 0.0118 - root_mean_squared_error: 0.1087 - val_loss: 0.0278 - val_root_mean_squared_error: 0.1667
# Epoch 139/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0117 - root_mean_squared_error: 0.1083 - val_loss: 0.0297 - val_root_mean_squared_error: 0.1725
# Epoch 140/150
# 673/673 [==============================] - 8s 12ms/step - loss: 0.0116 - root_mean_squared_error: 0.1075 - val_loss: 0.0284 - val_root_mean_squared_error: 0.1685
# Epoch 141/150
# 673/673 [==============================] - 8s 12ms/step - loss: 0.0110 - root_mean_squared_error: 0.1049 - val_loss: 0.0266 - val_root_mean_squared_error: 0.1630
# Epoch 142/150
# 673/673 [==============================] - 8s 12ms/step - loss: 0.0118 - root_mean_squared_error: 0.1084 - val_loss: 0.0281 - val_root_mean_squared_error: 0.1676
# Epoch 143/150
# 673/673 [==============================] - 8s 12ms/step - loss: 0.0116 - root_mean_squared_error: 0.1075 - val_loss: 0.0299 - val_root_mean_squared_error: 0.1729
# Epoch 144/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0120 - root_mean_squared_error: 0.1096 - val_loss: 0.0288 - val_root_mean_squared_error: 0.1696
# Epoch 145/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0114 - root_mean_squared_error: 0.1067 - val_loss: 0.0301 - val_root_mean_squared_error: 0.1734
# Epoch 146/150
# 673/673 [==============================] - 8s 12ms/step - loss: 0.0114 - root_mean_squared_error: 0.1070 - val_loss: 0.0292 - val_root_mean_squared_error: 0.1709
# Epoch 147/150
# 673/673 [==============================] - 8s 12ms/step - loss: 0.0110 - root_mean_squared_error: 0.1049 - val_loss: 0.0268 - val_root_mean_squared_error: 0.1638
# Epoch 148/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0114 - root_mean_squared_error: 0.1068 - val_loss: 0.0288 - val_root_mean_squared_error: 0.1698
# Epoch 149/150
# 673/673 [==============================] - 8s 12ms/step - loss: 0.0112 - root_mean_squared_error: 0.1059 - val_loss: 0.0291 - val_root_mean_squared_error: 0.1705
# Epoch 150/150
# 673/673 [==============================] - 8s 11ms/step - loss: 0.0110 - root_mean_squared_error: 0.1051 - val_loss: 0.0289 - val_root_mean_squared_error: 0.1700
# INFO:tensorflow:Assets written to: ./gdrive/My Drive/data/CSC/W4/W4633080500_encoded/assets

# %%
if retrain:
    fig, ax = plt.subplots(figsize=(10,5))

    ax.plot(lstm_ae_model.history['loss'], marker='.', label='loss')
    ax.plot(lstm_ae_model.history['val_loss'], marker='.', label='validation loss')

    ax.legend()
    ax.grid(True)

    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.savefig('epoches.png', dpi=300)
    plt.show()

# %%
synthetic_pd = pd.DataFrame.from_records([i[0] for i in synthetic_data])

# %% [markdown]
# # Validation

# %% [markdown]
# ## PCA

# %%
from sklearn.decomposition import PCA

pca_scale = PCA(n_components=2)
pca_scale = pca_scale.fit(X_source)

X_source_dr = pca_scale.transform(X_source)
x_min, x_max = X_source_dr.min(0), X_source_dr.max(0)
X_norm = (X_source_dr-x_min) / (x_max-x_min)  #Normalize
X_source_df = pd.DataFrame(X_norm, columns = ['dim1','dim2'])

X_target_dr = pca_scale.transform(X_target)
x_min, x_max = X_target_dr.min(0), X_target_dr.max(0)
X_norm = (X_target_dr-x_min) / (x_max-x_min)  #Normalize
X_target_df = pd.DataFrame(X_norm, columns = ['dim1','dim2'])

X_decoder_dr = pca_scale.transform(synthetic_pd)
x_min, x_max = X_decoder_dr.min(0), X_decoder_dr.max(0)
X_norm = (X_decoder_dr-x_min) / (x_max-x_min)  #Normalize
X_decode_df = pd.DataFrame(X_norm, columns = ['dim1','dim2'])

# %%
fig, ax = plt.subplots(figsize=(10,5))

ax.scatter(X_source_df['dim1'], X_source_df['dim2'], alpha=0.1, label='source')
ax.scatter(X_target_df['dim1'], X_target_df['dim2'], alpha=0.1, label='target')
ax.scatter(X_decode_df['dim1'], X_decode_df['dim2'], alpha=0.1, label='synthetic')

ax.legend()
ax.grid(True)

#plt.ylim(0, 1)
#plt.xlim(0, 1)
plt.savefig('distribution.png', dpi=300)
plt.show()

# %% [markdown]
# ## Model Cross Validation

# %%
model_source = svm.OneClassSVM(nu=0.01, kernel="rbf", gamma=0.01).fit(X_source)
model_target = svm.OneClassSVM(nu=0.01, kernel="rbf", gamma=0.01).fit(X_target)
model_synthetic = svm.OneClassSVM(nu=0.01, kernel="rbf", gamma=0.01).fit(synthetic_pd)

# %%
def scorer_(Y_pred):
    a = (Y_pred[Y_pred == -1].size)/(Y_pred.size)
    return a*100

# %%
def plot_score (score_list, date_list, tag):

    fig, ax = plt.subplots(figsize=(10, 3))
    plt.xticks(rotation=45)
    ax.plot(date_list, score_list, '.-')
    ax.set(xlabel='date', ylabel='score', title=tag)
    ax.grid()
    plt.ylim(0, 100)
    plt.tight_layout()
    #fig.savefig(path+tag+'-'+training_from.strftime("%Y%m%d")+'-'+training_to.strftime("%Y%m%d")+'.png', dpi=300)
    plt.show()

# %%
def get_score (data_df, start_date, end_date, normalizer, prediction_model):

    score_list = []
    date_list = []
    delta = datetime.timedelta(days=1)

    while start_date <= end_date:

        validation_df = data_df[(data_df['datetime'] > start_date) & 
                                (data_df['datetime'] <= start_date + delta)]

        
        if len(validation_df) > 0:

            validation_df_score = validation_df.drop(columns=drop_list)
            validation_df_score = normalizer.transform(validation_df_score)
            validation_df_score = prediction_model.predict(validation_df_score)

            score_list.append(scorer_(validation_df_score))
            date_list.append(start_date)

        start_date += delta
        
    return score_list, date_list

# %%
target_score_cv, target_date_cv = get_score(globals()[tag_dict['target']], 
                                            tag_dict['target_training_from'], 
                                            tag_dict['target_end'], 
                                            normalizer,
                                            model_source)

target_score, target_date = get_score(globals()[tag_dict['target']], 
                                            tag_dict['target_training_from'], 
                                            tag_dict['target_end'], 
                                            normalizer,
                                            model_target)

target_score_da, target_date_da = get_score(globals()[tag_dict['target']], 
                                            tag_dict['target_training_from'], 
                                            tag_dict['target_end'], 
                                            normalizer,
                                            model_synthetic)

# %%
def rmse(predictions, targets):
    return np.sqrt(((predictions - targets) ** 2).mean())

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(target_score_cv, target_score, squared=False)
# Out:
# 89.84965067626185

# %%
da_rmse = mean_squared_error(target_score_da, target_score, squared=False)
cv_rmse = mean_squared_error(target_score_cv, target_score, squared=False)



plot_score (target_score, target_date, 'Detect ' + tag_dict['target'] +' conditions by using '+ tag_dict['target'] +' model')

plot_score (target_score_cv, 
            target_date_cv, 
            'Detect ' + tag_dict['target'] +' conditions by using '+ tag_dict['source'] +' model, RMSE='+ "{:.3f}".format(cv_rmse))

plot_score (target_score_da, 
            target_date_da, 
            'Detect ' + tag_dict['target'] +' conditions by using '+ tag_dict['source'] +' synthetic model, RMSE=' + "{:.3f}".format(da_rmse))

# %% [markdown]
# ## Check Synthetic Data

# %%
feature_index = 206
duration = 26000
interval = 100
fig, ax = plt.subplots(figsize=(10,5))

ax.plot(range(duration, duration+interval), X_target[feature_index].head(duration).tail(interval), label='target', marker='.')
ax.plot(range(duration, duration+interval), X_source[feature_index].head(duration).tail(interval), label='source', marker='.')
ax.plot(range(duration, duration+interval), synthetic_pd[feature_index].head(duration).tail(interval), label='synthetic', marker='.')

ax.legend()
ax.grid(True)
plt.tight_layout()

#plt.savefig('distribution.png', dpi=300)
plt.show()
