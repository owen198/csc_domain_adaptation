# %% [markdown]
# <a href="https://colab.research.google.com/github/owen198/csc_domain_adaptation/blob/main/csc_lstm_ae(W4662FM0507).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# https://towardsdatascience.com/step-by-step-understanding-lstm-autoencoder-layers-ffab055b6352

from sklearn import preprocessing
from sklearn import svm
import pandas as pd
import datetime

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import random


from keras import metrics
from keras import models
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from keras.layers import Input, BatchNormalization, Activation
from keras.callbacks import EarlyStopping

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %% [markdown]
# # Load Data and proprecessing

# %%
tag_dict = {'target':'W4662FM0507',
            'target_training_from': datetime.datetime(2020,9,1,0,0),
            'target_training_to': datetime.datetime(2021,1,8,0,0),
            'target_end': datetime.datetime(2021,2,1,0,0),
            
            'source':'W4662FM0400',
            'source_training_from': datetime.datetime(2020,4,1,0,0), 
            'source_training_to': datetime.datetime(2020,6,1,0,0), 
            'source_end': datetime.datetime(2020,7,1,0,0)}

path = './gdrive/MyDrive/data/CSC/W4/'

# %%
globals()[tag_dict['source']] = pd.concat([pd.read_csv(path + tag_dict['source'] + '_202004.csv'),
                                          pd.read_csv(path + tag_dict['source'] + '_202005.csv'),
                                          pd.read_csv(path + tag_dict['source'] + '_202006.csv'),
                                          pd.read_csv(path + tag_dict['source'] + '_202007.csv'),
                                          pd.read_csv(path + tag_dict['source'] + '_202008.csv'),
                                          pd.read_csv(path + tag_dict['source'] + '_202009.csv')])

globals()[tag_dict['target']] = pd.concat([pd.read_csv(path + tag_dict['target'] + '_202009.csv'),
                                          pd.read_csv(path + tag_dict['target'] + '_202010.csv'),
                                          pd.read_csv(path + tag_dict['target'] + '_202011.csv'),
                                          pd.read_csv(path + tag_dict['target'] + '_202012.csv'),
                                          pd.read_csv(path + tag_dict['target'] + '_202101.csv'),
                                          pd.read_csv(path + tag_dict['target'] + '_202102.csv')])

# %%
globals()[tag_dict['source']]['datetime'] = globals()[tag_dict['source']]['timestamp'].astype('int').astype("datetime64[s]")
globals()[tag_dict['target']]['datetime'] = globals()[tag_dict['target']]['timestamp'].astype('int').astype("datetime64[s]")

# %%
globals()[tag_dict['source']+'_training'] = globals()[tag_dict['source']][
                                                  (globals()[tag_dict['source']]['datetime'] > tag_dict['source_training_from']) &
                                                  (globals()[tag_dict['source']]['datetime'] <= tag_dict['source_training_to']) ]

globals()[tag_dict['target']+'_training'] = globals()[tag_dict['target']][
                                                  (globals()[tag_dict['target']]['datetime'] > tag_dict['target_training_from']) &
                                                  (globals()[tag_dict['target']]['datetime'] <= tag_dict['target_training_to']) ]

# %%
drop_list = ['Unnamed: 0', '_id','type','scada','timestamp','device', 'datetime']

globals()[tag_dict['source']+'_training'] = globals()[tag_dict['source']+'_training'].drop(columns=drop_list)
globals()[tag_dict['target']+'_training'] = globals()[tag_dict['target']+'_training'].drop(columns=drop_list)

# %%
shape_min = min (globals()[tag_dict['source']+'_training'].shape[0], 
                 globals()[tag_dict['target']+'_training'].shape[0])
shape_max = max (globals()[tag_dict['source']+'_training'].shape[0], 
                 globals()[tag_dict['target']+'_training'].shape[0])

index = sorted(random.sample(range(0, shape_max), shape_min))

# %%
normalizer = preprocessing.MinMaxScaler()
normalizer = normalizer.fit(globals()[tag_dict['source']+'_training'])

X_source = pd.DataFrame(normalizer.transform(globals()[tag_dict['source']+'_training']))
X_target = pd.DataFrame(normalizer.transform(globals()[tag_dict['target']+'_training']))

# %%
def temporalize(X, y, lookback):
    output_X = []
    output_y = []
    for i in range(len(X)-lookback-1):
        t = []
        for j in range(1,lookback+1):
            # Gather past records upto the lookback period
            t.append(X[[(i+j+1)], :])
        output_X.append(t)
        output_y.append(y[i+lookback+1])
    return output_X, output_y

# %%
if len(X_target) > len(X_source):
    X = X_target.iloc[index]
    Y = X_source
else:
    X = X_target
    Y = X_source.iloc[index]


timesteps = 4
n_features = 390

#X, y = temporalize(X = timeseries, y = np.zeros(len(timeseries)), lookback = timesteps)
X, _ = temporalize(X = X.values, y = np.zeros(len(X)), lookback = timesteps)
Y, _ = temporalize(X = Y.values, y = np.zeros(len(Y)), lookback = timesteps)

X = np.array(X)
X = X.reshape(X.shape[0], timesteps, n_features)

Y = np.array(Y)
Y = Y.reshape(np.array(Y).shape[0], timesteps, n_features)

# %% [markdown]
# # LSTM-AE Model

# %%
def lstm_ae():
    # define model
    model = Sequential()
    model.add(LSTM(64, activation='relu', input_shape=(timesteps,n_features), return_sequences=True))
    model.add(LSTM(16, activation='relu', return_sequences=False))
    model.add(RepeatVector(timesteps))
    model.add(LSTM(16, activation='relu', return_sequences=True))
    model.add(LSTM(64, activation='relu', return_sequences=True))
    model.add(TimeDistributed(Dense(n_features)))
    model.compile(optimizer='adam', loss='mse', metrics=[metrics.RootMeanSquaredError()])
    model.summary()

    return model

# %%
model_name = './gdrive/My Drive/data/CSC/W4/' + tag_dict['target'] + '_encoded'
model_name
# Out:
# './gdrive/My Drive/data/CSC/W4/W4662FM0507_encoded'

# %%
retrain = True


if retrain:
    early_stopping = EarlyStopping(monitor='val_loss', patience=150, verbose=2)

    model = lstm_ae ()
    lstm_ae_model = model.fit(Y, X, epochs=150, batch_size=16, verbose=1, validation_split=0.2, callbacks=[early_stopping])
    model.save(model_name)
else:
    model = models.load_model(model_name)  
    

#model = models.load_model(model_name)    
synthetic_data = model.predict(X, verbose=0)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 4, 64)             116480
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 16)                5184
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 4, 16)             0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 4, 16)             2112
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 4, 64)             20736
# _________________________________________________________________
# time_distributed (TimeDistri (None, 4, 390)            25350
# =================================================================
# Total params: 169,862
# Trainable params: 169,862
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/150
# 2584/2584 [==============================] - 28s 10ms/step - loss: 0.0419 - root_mean_squared_error: 0.1896 - val_loss: 0.0159 - val_root_mean_squared_error: 0.1263
# Epoch 2/150
# 2584/2584 [==============================] - 24s 9ms/step - loss: 0.0166 - root_mean_squared_error: 0.1286 - val_loss: 0.0157 - val_root_mean_squared_error: 0.1254
# Epoch 3/150
# 2584/2584 [==============================] - 24s 9ms/step - loss: 0.0134 - root_mean_squared_error: 0.1159 - val_loss: 0.0161 - val_root_mean_squared_error: 0.1269
# Epoch 4/150
# 2584/2584 [==============================] - 24s 9ms/step - loss: 0.0117 - root_mean_squared_error: 0.1080 - val_loss: 0.0189 - val_root_mean_squared_error: 0.1373
# Epoch 5/150
# 2584/2584 [==============================] - 24s 9ms/step - loss: 0.0109 - root_mean_squared_error: 0.1042 - val_loss: 0.0194 - val_root_mean_squared_error: 0.1393
# Epoch 6/150
# 2584/2584 [==============================] - 24s 9ms/step - loss: 0.0103 - root_mean_squared_error: 0.1017 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1334
# Epoch 7/150
# 2584/2584 [==============================] - 24s 9ms/step - loss: 0.0094 - root_mean_squared_error: 0.0969 - val_loss: 0.0198 - val_root_mean_squared_error: 0.1407
# Epoch 8/150
# 2584/2584 [==============================] - 24s 9ms/step - loss: 0.0090 - root_mean_squared_error: 0.0948 - val_loss: 0.0198 - val_root_mean_squared_error: 0.1407
# Epoch 9/150
# 2584/2584 [==============================] - 24s 9ms/step - loss: 0.0086 - root_mean_squared_error: 0.0925 - val_loss: 0.0205 - val_root_mean_squared_error: 0.1432
# Epoch 10/150
# 2584/2584 [==============================] - 24s 9ms/step - loss: 0.0081 - root_mean_squared_error: 0.0902 - val_loss: 0.0245 - val_root_mean_squared_error: 0.1564
# Epoch 11/150
# 2584/2584 [==============================] - 24s 9ms/step - loss: 0.0080 - root_mean_squared_error: 0.0894 - val_loss: 0.0234 - val_root_mean_squared_error: 0.1529
# Epoch 12/150
# 2584/2584 [==============================] - 24s 9ms/step - loss: 0.0076 - root_mean_squared_error: 0.0870 - val_loss: 0.0213 - val_root_mean_squared_error: 0.1459
# Epoch 13/150
# 2584/2584 [==============================] - 24s 9ms/step - loss: 0.0074 - root_mean_squared_error: 0.0862 - val_loss: 0.0203 - val_root_mean_squared_error: 0.1425
# Epoch 14/150
# 2584/2584 [==============================] - 24s 9ms/step - loss: 0.0071 - root_mean_squared_error: 0.0840 - val_loss: 0.0216 - val_root_mean_squared_error: 0.1468
# Epoch 15/150
# 2584/2584 [==============================] - 24s 9ms/step - loss: 0.0071 - root_mean_squared_error: 0.0841 - val_loss: 0.0213 - val_root_mean_squared_error: 0.1460
# Epoch 16/150
# 2584/2584 [==============================] - 24s 9ms/step - loss: 0.0068 - root_mean_squared_error: 0.0823 - val_loss: 0.0238 - val_root_mean_squared_error: 0.1542
# Epoch 17/150
# 2584/2584 [==============================] - 24s 9ms/step - loss: 0.0066 - root_mean_squared_error: 0.0811 - val_loss: 0.0243 - val_root_mean_squared_error: 0.1558
# Epoch 18/150
# 2584/2584 [==============================] - 24s 9ms/step - loss: 0.0064 - root_mean_squared_error: 0.0799 - val_loss: 0.0217 - val_root_mean_squared_error: 0.1472
# Epoch 19/150
# 2584/2584 [==============================] - 24s 9ms/step - loss: 0.0064 - root_mean_squared_error: 0.0799 - val_loss: 0.0214 - val_root_mean_squared_error: 0.1463
# Epoch 20/150
# 2584/2584 [==============================] - 24s 9ms/step - loss: 0.0061 - root_mean_squared_error: 0.0783 - val_loss: 0.0233 - val_root_mean_squared_error: 0.1525
# Epoch 21/150
# 2584/2584 [==============================] - 24s 9ms/step - loss: 0.0062 - root_mean_squared_error: 0.0787 - val_loss: 0.0222 - val_root_mean_squared_error: 0.1490
# Epoch 22/150
# 2584/2584 [==============================] - 24s 9ms/step - loss: 0.0060 - root_mean_squared_error: 0.0775 - val_loss: 0.0258 - val_root_mean_squared_error: 0.1606
# Epoch 23/150
# 2584/2584 [==============================] - 24s 9ms/step - loss: 0.0060 - root_mean_squared_error: 0.0775 - val_loss: 0.0224 - val_root_mean_squared_error: 0.1496
# Epoch 24/150
# 2584/2584 [==============================] - 24s 9ms/step - loss: 0.0057 - root_mean_squared_error: 0.0755 - val_loss: 0.0233 - val_root_mean_squared_error: 0.1526
# Epoch 25/150
# 2584/2584 [==============================] - 24s 9ms/step - loss: 0.0059 - root_mean_squared_error: 0.0767 - val_loss: 0.0249 - val_root_mean_squared_error: 0.1578
# Epoch 26/150
# 2584/2584 [==============================] - 24s 9ms/step - loss: 0.0056 - root_mean_squared_error: 0.0746 - val_loss: 0.0223 - val_root_mean_squared_error: 0.1492
# Epoch 27/150
# 2584/2584 [==============================] - 24s 9ms/step - loss: 0.0055 - root_mean_squared_error: 0.0739 - val_loss: 0.0238 - val_root_mean_squared_error: 0.1543
# Epoch 28/150
# 2584/2584 [==============================] - 24s 9ms/step - loss: 0.0054 - root_mean_squared_error: 0.0736 - val_loss: 0.0234 - val_root_mean_squared_error: 0.1529
# Epoch 29/150
# 2584/2584 [==============================] - 24s 9ms/step - loss: 0.0053 - root_mean_squared_error: 0.0729 - val_loss: 0.0254 - val_root_mean_squared_error: 0.1593
# Epoch 30/150
# 2584/2584 [==============================] - 24s 9ms/step - loss: 0.0052 - root_mean_squared_error: 0.0721 - val_loss: 0.0227 - val_root_mean_squared_error: 0.1506
# Epoch 31/150
# 2584/2584 [==============================] - 24s 9ms/step - loss: 0.0051 - root_mean_squared_error: 0.0712 - val_loss: 0.0243 - val_root_mean_squared_error: 0.1559
# Epoch 32/150
# 2584/2584 [==============================] - 24s 9ms/step - loss: 0.0051 - root_mean_squared_error: 0.0712 - val_loss: 0.0240 - val_root_mean_squared_error: 0.1548
# Epoch 33/150
# 2584/2584 [==============================] - 24s 9ms/step - loss: 0.0052 - root_mean_squared_error: 0.0718 - val_loss: 0.0234 - val_root_mean_squared_error: 0.1529
# Epoch 34/150
# 2584/2584 [==============================] - 24s 9ms/step - loss: 0.0050 - root_mean_squared_error: 0.0704 - val_loss: 0.0253 - val_root_mean_squared_error: 0.1592
# Epoch 35/150
# 2584/2584 [==============================] - 24s 9ms/step - loss: 0.0051 - root_mean_squared_error: 0.0715 - val_loss: 0.0240 - val_root_mean_squared_error: 0.1549
# Epoch 36/150
# 2584/2584 [==============================] - 24s 9ms/step - loss: 0.0051 - root_mean_squared_error: 0.0712 - val_loss: 0.0263 - val_root_mean_squared_error: 0.1622
# Epoch 37/150
# 2584/2584 [==============================] - 24s 9ms/step - loss: 0.0048 - root_mean_squared_error: 0.0695 - val_loss: 0.0241 - val_root_mean_squared_error: 0.1553
# Epoch 38/150
# 2584/2584 [==============================] - 24s 9ms/step - loss: 0.0047 - root_mean_squared_error: 0.0689 - val_loss: 0.0210 - val_root_mean_squared_error: 0.1448
# Epoch 39/150
# 2584/2584 [==============================] - 24s 9ms/step - loss: 0.0050 - root_mean_squared_error: 0.0704 - val_loss: 0.0237 - val_root_mean_squared_error: 0.1540
# Epoch 40/150
# 2584/2584 [==============================] - 24s 9ms/step - loss: 0.0048 - root_mean_squared_error: 0.0690 - val_loss: 0.0232 - val_root_mean_squared_error: 0.1522
# Epoch 41/150
# 2584/2584 [==============================] - 24s 9ms/step - loss: 0.0047 - root_mean_squared_error: 0.0683 - val_loss: 0.0218 - val_root_mean_squared_error: 0.1477
# Epoch 42/150
# 2584/2584 [==============================] - 24s 9ms/step - loss: 0.0047 - root_mean_squared_error: 0.0688 - val_loss: 0.0195 - val_root_mean_squared_error: 0.1398
# Epoch 43/150
# 2584/2584 [==============================] - 24s 9ms/step - loss: 0.0048 - root_mean_squared_error: 0.0690 - val_loss: 0.0229 - val_root_mean_squared_error: 0.1512
# Epoch 44/150
# 2584/2584 [==============================] - 25s 9ms/step - loss: 0.0046 - root_mean_squared_error: 0.0681 - val_loss: 0.0251 - val_root_mean_squared_error: 0.1583
# Epoch 45/150
# 2584/2584 [==============================] - 24s 9ms/step - loss: 0.0047 - root_mean_squared_error: 0.0683 - val_loss: 0.0254 - val_root_mean_squared_error: 0.1593
# Epoch 46/150
# 2584/2584 [==============================] - 24s 9ms/step - loss: 0.0045 - root_mean_squared_error: 0.0674 - val_loss: 0.0255 - val_root_mean_squared_error: 0.1598
# Epoch 47/150
# 2584/2584 [==============================] - 24s 9ms/step - loss: 0.0046 - root_mean_squared_error: 0.0675 - val_loss: 0.0254 - val_root_mean_squared_error: 0.1595
# Epoch 48/150
# 2584/2584 [==============================] - 25s 9ms/step - loss: 0.0047 - root_mean_squared_error: 0.0684 - val_loss: 0.0234 - val_root_mean_squared_error: 0.1528
# Epoch 49/150
# 2584/2584 [==============================] - 25s 9ms/step - loss: 0.0044 - root_mean_squared_error: 0.0662 - val_loss: 0.0242 - val_root_mean_squared_error: 0.1555
# Epoch 50/150
# 2584/2584 [==============================] - 24s 9ms/step - loss: 0.0049 - root_mean_squared_error: 0.0697 - val_loss: 0.0265 - val_root_mean_squared_error: 0.1628
# Epoch 51/150
# 2584/2584 [==============================] - 24s 9ms/step - loss: 0.0045 - root_mean_squared_error: 0.0673 - val_loss: 0.0242 - val_root_mean_squared_error: 0.1556
# Epoch 52/150
# 2584/2584 [==============================] - 24s 9ms/step - loss: 0.0045 - root_mean_squared_error: 0.0673 - val_loss: 0.0237 - val_root_mean_squared_error: 0.1540
# Epoch 53/150
# 2584/2584 [==============================] - 24s 9ms/step - loss: 0.0045 - root_mean_squared_error: 0.0671 - val_loss: 0.0233 - val_root_mean_squared_error: 0.1525
# Epoch 54/150
# 2584/2584 [==============================] - 25s 9ms/step - loss: 0.0043 - root_mean_squared_error: 0.0659 - val_loss: 0.0229 - val_root_mean_squared_error: 0.1512
# Epoch 55/150
# 2584/2584 [==============================] - 25s 9ms/step - loss: 0.0047 - root_mean_squared_error: 0.0686 - val_loss: 0.0240 - val_root_mean_squared_error: 0.1548
# Epoch 56/150
# 2584/2584 [==============================] - 25s 9ms/step - loss: 0.0042 - root_mean_squared_error: 0.0650 - val_loss: 0.0210 - val_root_mean_squared_error: 0.1449
# Epoch 57/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0042 - root_mean_squared_error: 0.0650 - val_loss: 0.0246 - val_root_mean_squared_error: 0.1569
# Epoch 58/150
# 2584/2584 [==============================] - 25s 9ms/step - loss: 0.0048 - root_mean_squared_error: 0.0690 - val_loss: 0.0259 - val_root_mean_squared_error: 0.1609
# Epoch 59/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0042 - root_mean_squared_error: 0.0650 - val_loss: 0.0230 - val_root_mean_squared_error: 0.1517
# Epoch 60/150
# 2584/2584 [==============================] - 24s 9ms/step - loss: 0.0042 - root_mean_squared_error: 0.0651 - val_loss: 0.0238 - val_root_mean_squared_error: 0.1544
# Epoch 61/150
# 2584/2584 [==============================] - 25s 9ms/step - loss: 0.0045 - root_mean_squared_error: 0.0674 - val_loss: 0.0245 - val_root_mean_squared_error: 0.1565
# Epoch 62/150
# 2584/2584 [==============================] - 25s 9ms/step - loss: 0.0044 - root_mean_squared_error: 0.0662 - val_loss: 0.0234 - val_root_mean_squared_error: 0.1530
# Epoch 63/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0042 - root_mean_squared_error: 0.0646 - val_loss: 0.0268 - val_root_mean_squared_error: 0.1638
# Epoch 64/150
# 2584/2584 [==============================] - 25s 9ms/step - loss: 0.0041 - root_mean_squared_error: 0.0643 - val_loss: 0.0247 - val_root_mean_squared_error: 0.1572
# Epoch 65/150
# 2584/2584 [==============================] - 25s 9ms/step - loss: 0.0042 - root_mean_squared_error: 0.0645 - val_loss: 0.0233 - val_root_mean_squared_error: 0.1526
# Epoch 66/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0042 - root_mean_squared_error: 0.0651 - val_loss: 0.0245 - val_root_mean_squared_error: 0.1565
# Epoch 67/150
# 2584/2584 [==============================] - 25s 9ms/step - loss: 0.0043 - root_mean_squared_error: 0.0653 - val_loss: 0.0242 - val_root_mean_squared_error: 0.1557
# Epoch 68/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0042 - root_mean_squared_error: 0.0646 - val_loss: 0.0261 - val_root_mean_squared_error: 0.1615
# Epoch 69/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0042 - root_mean_squared_error: 0.0649 - val_loss: 0.0263 - val_root_mean_squared_error: 0.1620
# Epoch 70/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0041 - root_mean_squared_error: 0.0643 - val_loss: 0.0256 - val_root_mean_squared_error: 0.1601
# Epoch 71/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0042 - root_mean_squared_error: 0.0652 - val_loss: 0.0236 - val_root_mean_squared_error: 0.1535
# Epoch 72/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0041 - root_mean_squared_error: 0.0638 - val_loss: 0.0259 - val_root_mean_squared_error: 0.1610
# Epoch 73/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0041 - root_mean_squared_error: 0.0639 - val_loss: 0.0240 - val_root_mean_squared_error: 0.1548
# Epoch 74/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0043 - root_mean_squared_error: 0.0654 - val_loss: 0.0247 - val_root_mean_squared_error: 0.1571
# Epoch 75/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0041 - root_mean_squared_error: 0.0640 - val_loss: 0.0271 - val_root_mean_squared_error: 0.1646
# Epoch 76/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0040 - root_mean_squared_error: 0.0636 - val_loss: 0.0254 - val_root_mean_squared_error: 0.1594
# Epoch 77/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0039 - root_mean_squared_error: 0.0625 - val_loss: 0.0241 - val_root_mean_squared_error: 0.1553
# Epoch 78/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0039 - root_mean_squared_error: 0.0628 - val_loss: 0.0235 - val_root_mean_squared_error: 0.1534
# Epoch 79/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0042 - root_mean_squared_error: 0.0651 - val_loss: 0.0241 - val_root_mean_squared_error: 0.1551
# Epoch 80/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0041 - root_mean_squared_error: 0.0639 - val_loss: 0.0231 - val_root_mean_squared_error: 0.1520
# Epoch 81/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0042 - root_mean_squared_error: 0.0652 - val_loss: 0.0255 - val_root_mean_squared_error: 0.1597
# Epoch 82/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0041 - root_mean_squared_error: 0.0640 - val_loss: 0.0225 - val_root_mean_squared_error: 0.1501
# Epoch 83/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0038 - root_mean_squared_error: 0.0620 - val_loss: 0.0253 - val_root_mean_squared_error: 0.1591
# Epoch 84/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0040 - root_mean_squared_error: 0.0634 - val_loss: 0.0255 - val_root_mean_squared_error: 0.1597
# Epoch 85/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0042 - root_mean_squared_error: 0.0645 - val_loss: 0.0268 - val_root_mean_squared_error: 0.1636
# Epoch 86/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0040 - root_mean_squared_error: 0.0632 - val_loss: 0.0234 - val_root_mean_squared_error: 0.1528
# Epoch 87/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0038 - root_mean_squared_error: 0.0613 - val_loss: 0.0232 - val_root_mean_squared_error: 0.1523
# Epoch 88/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0039 - root_mean_squared_error: 0.0627 - val_loss: 0.0251 - val_root_mean_squared_error: 0.1584
# Epoch 89/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0038 - root_mean_squared_error: 0.0615 - val_loss: 0.0241 - val_root_mean_squared_error: 0.1552
# Epoch 90/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0038 - root_mean_squared_error: 0.0612 - val_loss: 0.0249 - val_root_mean_squared_error: 0.1578
# Epoch 91/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0038 - root_mean_squared_error: 0.0616 - val_loss: 0.0239 - val_root_mean_squared_error: 0.1544
# Epoch 92/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0039 - root_mean_squared_error: 0.0626 - val_loss: 0.0265 - val_root_mean_squared_error: 0.1626
# Epoch 93/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0037 - root_mean_squared_error: 0.0607 - val_loss: 0.0239 - val_root_mean_squared_error: 0.1546
# Epoch 94/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0041 - root_mean_squared_error: 0.0639 - val_loss: 0.0258 - val_root_mean_squared_error: 0.1607
# Epoch 95/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0040 - root_mean_squared_error: 0.0635 - val_loss: 0.0252 - val_root_mean_squared_error: 0.1586
# Epoch 96/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0039 - root_mean_squared_error: 0.0627 - val_loss: 0.0233 - val_root_mean_squared_error: 0.1527
# Epoch 97/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0039 - root_mean_squared_error: 0.0625 - val_loss: 0.0246 - val_root_mean_squared_error: 0.1568
# Epoch 98/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0039 - root_mean_squared_error: 0.0621 - val_loss: 0.0268 - val_root_mean_squared_error: 0.1638
# Epoch 99/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0037 - root_mean_squared_error: 0.0611 - val_loss: 0.0250 - val_root_mean_squared_error: 0.1582
# Epoch 100/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0038 - root_mean_squared_error: 0.0616 - val_loss: 0.0260 - val_root_mean_squared_error: 0.1611
# Epoch 101/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0041 - root_mean_squared_error: 0.0641 - val_loss: 0.0267 - val_root_mean_squared_error: 0.1633
# Epoch 102/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0038 - root_mean_squared_error: 0.0617 - val_loss: 0.0246 - val_root_mean_squared_error: 0.1570
# Epoch 103/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0038 - root_mean_squared_error: 0.0615 - val_loss: 0.0236 - val_root_mean_squared_error: 0.1537
# Epoch 104/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0039 - root_mean_squared_error: 0.0621 - val_loss: 0.0263 - val_root_mean_squared_error: 0.1621
# Epoch 105/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0038 - root_mean_squared_error: 0.0620 - val_loss: 0.0239 - val_root_mean_squared_error: 0.1548
# Epoch 106/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0041 - root_mean_squared_error: 0.0643 - val_loss: 0.0255 - val_root_mean_squared_error: 0.1597
# Epoch 107/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0037 - root_mean_squared_error: 0.0605 - val_loss: 0.0246 - val_root_mean_squared_error: 0.1569
# Epoch 108/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0037 - root_mean_squared_error: 0.0611 - val_loss: 0.0239 - val_root_mean_squared_error: 0.1546
# Epoch 109/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0037 - root_mean_squared_error: 0.0607 - val_loss: 0.0239 - val_root_mean_squared_error: 0.1545
# Epoch 110/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0037 - root_mean_squared_error: 0.0609 - val_loss: 0.0246 - val_root_mean_squared_error: 0.1567
# Epoch 111/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0036 - root_mean_squared_error: 0.0600 - val_loss: 0.0247 - val_root_mean_squared_error: 0.1572
# Epoch 112/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0043 - root_mean_squared_error: 0.0658 - val_loss: 0.0235 - val_root_mean_squared_error: 0.1532
# Epoch 113/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0037 - root_mean_squared_error: 0.0610 - val_loss: 0.0239 - val_root_mean_squared_error: 0.1546
# Epoch 114/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0038 - root_mean_squared_error: 0.0617 - val_loss: 0.0243 - val_root_mean_squared_error: 0.1558
# Epoch 115/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0035 - root_mean_squared_error: 0.0595 - val_loss: 0.0234 - val_root_mean_squared_error: 0.1529
# Epoch 116/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0037 - root_mean_squared_error: 0.0605 - val_loss: 0.0258 - val_root_mean_squared_error: 0.1605
# Epoch 117/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0041 - root_mean_squared_error: 0.0640 - val_loss: 0.0256 - val_root_mean_squared_error: 0.1600
# Epoch 118/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0037 - root_mean_squared_error: 0.0606 - val_loss: 0.0239 - val_root_mean_squared_error: 0.1545
# Epoch 119/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0040 - root_mean_squared_error: 0.0635 - val_loss: 0.0234 - val_root_mean_squared_error: 0.1530
# Epoch 120/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0037 - root_mean_squared_error: 0.0609 - val_loss: 0.0247 - val_root_mean_squared_error: 0.1571
# Epoch 121/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0036 - root_mean_squared_error: 0.0600 - val_loss: 0.0237 - val_root_mean_squared_error: 0.1541
# Epoch 122/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0037 - root_mean_squared_error: 0.0608 - val_loss: 0.0237 - val_root_mean_squared_error: 0.1539
# Epoch 123/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0036 - root_mean_squared_error: 0.0601 - val_loss: 0.0270 - val_root_mean_squared_error: 0.1643
# Epoch 124/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0037 - root_mean_squared_error: 0.0608 - val_loss: 0.0245 - val_root_mean_squared_error: 0.1566
# Epoch 125/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0037 - root_mean_squared_error: 0.0606 - val_loss: 0.0255 - val_root_mean_squared_error: 0.1597
# Epoch 126/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0037 - root_mean_squared_error: 0.0605 - val_loss: 0.0244 - val_root_mean_squared_error: 0.1564
# Epoch 127/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0037 - root_mean_squared_error: 0.0607 - val_loss: 0.0230 - val_root_mean_squared_error: 0.1516
# Epoch 128/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0034 - root_mean_squared_error: 0.0585 - val_loss: 0.0237 - val_root_mean_squared_error: 0.1539
# Epoch 129/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0036 - root_mean_squared_error: 0.0601 - val_loss: 0.0222 - val_root_mean_squared_error: 0.1490
# Epoch 130/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0036 - root_mean_squared_error: 0.0598 - val_loss: 0.0252 - val_root_mean_squared_error: 0.1587
# Epoch 131/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0035 - root_mean_squared_error: 0.0592 - val_loss: 0.0230 - val_root_mean_squared_error: 0.1518
# Epoch 132/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0040 - root_mean_squared_error: 0.0632 - val_loss: 0.0234 - val_root_mean_squared_error: 0.1529
# Epoch 133/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0036 - root_mean_squared_error: 0.0600 - val_loss: 0.0241 - val_root_mean_squared_error: 0.1552
# Epoch 134/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0035 - root_mean_squared_error: 0.0587 - val_loss: 0.0237 - val_root_mean_squared_error: 0.1538
# Epoch 135/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0036 - root_mean_squared_error: 0.0599 - val_loss: 0.0241 - val_root_mean_squared_error: 0.1554
# Epoch 136/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0040 - root_mean_squared_error: 0.0630 - val_loss: 0.0236 - val_root_mean_squared_error: 0.1537
# Epoch 137/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0034 - root_mean_squared_error: 0.0587 - val_loss: 0.0230 - val_root_mean_squared_error: 0.1516
# Epoch 138/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0039 - root_mean_squared_error: 0.0623 - val_loss: 0.0243 - val_root_mean_squared_error: 0.1557
# Epoch 139/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0040 - root_mean_squared_error: 0.0629 - val_loss: 0.0247 - val_root_mean_squared_error: 0.1571
# Epoch 140/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0034 - root_mean_squared_error: 0.0580 - val_loss: 0.0258 - val_root_mean_squared_error: 0.1607
# Epoch 141/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0038 - root_mean_squared_error: 0.0617 - val_loss: 0.0275 - val_root_mean_squared_error: 0.1657
# Epoch 142/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0037 - root_mean_squared_error: 0.0605 - val_loss: 0.0250 - val_root_mean_squared_error: 0.1581
# Epoch 143/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0038 - root_mean_squared_error: 0.0613 - val_loss: 0.0363 - val_root_mean_squared_error: 0.1905
# Epoch 144/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0048 - root_mean_squared_error: 0.0689 - val_loss: 0.0239 - val_root_mean_squared_error: 0.1546
# Epoch 145/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0036 - root_mean_squared_error: 0.0603 - val_loss: 0.0256 - val_root_mean_squared_error: 0.1601
# Epoch 146/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0034 - root_mean_squared_error: 0.0585 - val_loss: 0.0244 - val_root_mean_squared_error: 0.1561
# Epoch 147/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0037 - root_mean_squared_error: 0.0608 - val_loss: 0.0245 - val_root_mean_squared_error: 0.1564
# Epoch 148/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0034 - root_mean_squared_error: 0.0584 - val_loss: 0.0249 - val_root_mean_squared_error: 0.1577
# Epoch 149/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0036 - root_mean_squared_error: 0.0597 - val_loss: 0.0228 - val_root_mean_squared_error: 0.1512
# Epoch 150/150
# 2584/2584 [==============================] - 25s 10ms/step - loss: 0.0039 - root_mean_squared_error: 0.0627 - val_loss: 0.0236 - val_root_mean_squared_error: 0.1535
# INFO:tensorflow:Assets written to: ./gdrive/My Drive/data/CSC/W4/W4662FM0507_encoded/assets

# %%
if retrain:
    fig, ax = plt.subplots(figsize=(10,5))

    ax.plot(lstm_ae_model.history['loss'], marker='.', label='loss')
    ax.plot(lstm_ae_model.history['val_loss'], marker='.', label='validation loss')

    ax.legend()
    ax.grid(True)

    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.savefig('epoches.png', dpi=300)
    plt.show()

# %%
synthetic_pd = pd.DataFrame.from_records([i[0] for i in synthetic_data])

# %% [markdown]
# # Validation

# %% [markdown]
# ## PCA

# %%
from sklearn.decomposition import PCA

pca_scale = PCA(n_components=2)
pca_scale = pca_scale.fit(X_source)

X_source_dr = pca_scale.transform(X_source)
x_min, x_max = X_source_dr.min(0), X_source_dr.max(0)
X_norm = (X_source_dr-x_min) / (x_max-x_min)  #Normalize
X_source_df = pd.DataFrame(X_norm, columns = ['dim1','dim2'])

X_target_dr = pca_scale.transform(X_target)
x_min, x_max = X_target_dr.min(0), X_target_dr.max(0)
X_norm = (X_target_dr-x_min) / (x_max-x_min)  #Normalize
X_target_df = pd.DataFrame(X_norm, columns = ['dim1','dim2'])

X_decoder_dr = pca_scale.transform(synthetic_pd)
x_min, x_max = X_decoder_dr.min(0), X_decoder_dr.max(0)
X_norm = (X_decoder_dr-x_min) / (x_max-x_min)  #Normalize
X_decode_df = pd.DataFrame(X_norm, columns = ['dim1','dim2'])

# %%
fig, ax = plt.subplots(figsize=(10,5))

ax.scatter(X_source_df['dim1'], X_source_df['dim2'], alpha=0.1, label='source')
ax.scatter(X_target_df['dim1'], X_target_df['dim2'], alpha=0.1, label='target')
ax.scatter(X_decode_df['dim1'], X_decode_df['dim2'], alpha=0.1, label='decode')

ax.legend()
ax.grid(True)

#plt.ylim(0, 1)
#plt.xlim(0, 1)
plt.savefig('distribution.png', dpi=300)
plt.show()

# %% [markdown]
# ## Model Cross Validation

# %%
model_source = svm.OneClassSVM(nu=0.01, kernel="rbf", gamma=0.01).fit(X_source)
model_target = svm.OneClassSVM(nu=0.01, kernel="rbf", gamma=0.01).fit(X_target)
model_synthetic = svm.OneClassSVM(nu=0.01, kernel="rbf", gamma=0.01).fit(synthetic_pd)

# %%
def scorer_(Y_pred):
    a = (Y_pred[Y_pred == -1].size)/(Y_pred.size)
    return a*100

# %%
def plot_score (score_list, date_list, tag):

    fig, ax = plt.subplots(figsize=(10, 3))
    plt.xticks(rotation=45)
    ax.plot(date_list, score_list, '.-')
    ax.set(xlabel='date', ylabel='score', title=tag)
    ax.grid()
    plt.ylim(0, 100)
    plt.tight_layout()
    #fig.savefig(path+tag+'-'+training_from.strftime("%Y%m%d")+'-'+training_to.strftime("%Y%m%d")+'.png', dpi=300)
    plt.show()

# %%
def get_score (data_df, start_date, end_date, normalizer, prediction_model):

    score_list = []
    date_list = []
    delta = datetime.timedelta(days=1)

    while start_date <= end_date:

        validation_df = data_df[(data_df['datetime'] > start_date) & 
                                (data_df['datetime'] <= start_date + delta)]

        
        if len(validation_df) > 0:

            validation_df_score = validation_df.drop(columns=drop_list)
            validation_df_score = normalizer.transform(validation_df_score)
            validation_df_score = prediction_model.predict(validation_df_score)

            score_list.append(scorer_(validation_df_score))
            date_list.append(start_date)

        start_date += delta
        
    return score_list, date_list

# %%
target_score_cv, target_date_cv = get_score(globals()[tag_dict['target']], 
                                            tag_dict['target_training_from'], 
                                            tag_dict['target_end'], 
                                            normalizer,
                                            model_source)

target_score, target_date = get_score(globals()[tag_dict['target']], 
                                            tag_dict['target_training_from'], 
                                            tag_dict['target_end'], 
                                            normalizer,
                                            model_target)

target_score_da, target_date_da = get_score(globals()[tag_dict['target']], 
                                            tag_dict['target_training_from'], 
                                            tag_dict['target_end'], 
                                            normalizer,
                                            model_synthetic)

# %%
def rmse(predictions, targets):
    return np.sqrt(((predictions - targets) ** 2).mean())

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(target_score_cv, target_score, squared=False)
# Out:
# 58.49518515015864

# %%
da_rmse = mean_squared_error(target_score_da, target_score, squared=False)
cv_rmse = mean_squared_error(target_score_cv, target_score, squared=False)



plot_score (target_score, target_date, 'Detect ' + tag_dict['target'] +' conditions by using '+ tag_dict['target'] +' model')

plot_score (target_score_cv, 
            target_date_cv, 
            'Detect ' + tag_dict['target'] +' conditions by using '+ tag_dict['source'] +' model, RMSE='+ "{:.3f}".format(cv_rmse))

plot_score (target_score_da, 
            target_date_da, 
            'Detect ' + tag_dict['target'] +' conditions by using '+ tag_dict['source'] +' synthetic model, RMSE=' + "{:.3f}".format(da_rmse))

# %% [markdown]
# ## Check Synthetic Data

# %%
feature_index = 206
duration = 26000
interval = 100
fig, ax = plt.subplots(figsize=(10,5))

ax.plot(range(duration, duration+interval), X_target[feature_index].head(duration).tail(interval), label='target', marker='.')
ax.plot(range(duration, duration+interval), X_source[feature_index].head(duration).tail(interval), label='source', marker='.')
ax.plot(range(duration, duration+interval), synthetic_pd[feature_index].head(duration).tail(interval), label='synthetic', marker='.')

ax.legend()
ax.grid(True)
plt.tight_layout()

#plt.savefig('distribution.png', dpi=300)
plt.show()
