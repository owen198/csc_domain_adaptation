# %% [markdown]
# <a href="https://colab.research.google.com/github/owen198/csc_domain_adaptation/blob/main/csc_lstm_ae(W4662FM0507%08_W4662FM0400).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# https://towardsdatascience.com/step-by-step-understanding-lstm-autoencoder-layers-ffab055b6352

from sklearn import preprocessing
from sklearn import svm
import pandas as pd
import datetime

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import random


from keras import metrics
from keras import models
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from keras.layers import Input, BatchNormalization, Activation
from keras.callbacks import EarlyStopping

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %% [markdown]
# # Load Data and proprecessing

# %%
tag_dict = {'source':'W4662FM0507',
            'source_training_from': datetime.datetime(2020,9,1,0,0),
            'source_training_to': datetime.datetime(2021,1,8,0,0),
            'source_end': datetime.datetime(2021,2,1,0,0),
            
            'target':'W4662FM0400',
            'target_training_from': datetime.datetime(2020,4,1,0,0), 
            'target_training_to': datetime.datetime(2020,6,1,0,0), 
            'target_end': datetime.datetime(2020,7,1,0,0)}

path = './gdrive/MyDrive/data/CSC/W4/'

# %%
globals()[tag_dict['target']] = pd.concat([pd.read_csv(path + tag_dict['target'] + '_202004.csv'),
                                          pd.read_csv(path + tag_dict['target'] + '_202005.csv'),
                                          pd.read_csv(path + tag_dict['target'] + '_202006.csv'),
                                          pd.read_csv(path + tag_dict['target'] + '_202007.csv'),
                                          pd.read_csv(path + tag_dict['target'] + '_202008.csv'),
                                          pd.read_csv(path + tag_dict['target'] + '_202009.csv')])

globals()[tag_dict['source']] = pd.concat([pd.read_csv(path + tag_dict['source'] + '_202009.csv'),
                                          pd.read_csv(path + tag_dict['source'] + '_202010.csv'),
                                          pd.read_csv(path + tag_dict['source'] + '_202011.csv'),
                                          pd.read_csv(path + tag_dict['source'] + '_202012.csv'),
                                          pd.read_csv(path + tag_dict['source'] + '_202101.csv'),
                                          pd.read_csv(path + tag_dict['source'] + '_202102.csv')])

# %%
globals()[tag_dict['source']]['datetime'] = globals()[tag_dict['source']]['timestamp'].astype('int').astype("datetime64[s]")
globals()[tag_dict['target']]['datetime'] = globals()[tag_dict['target']]['timestamp'].astype('int').astype("datetime64[s]")

# %%
globals()[tag_dict['source']+'_training'] = globals()[tag_dict['source']][
                                                  (globals()[tag_dict['source']]['datetime'] > tag_dict['source_training_from']) &
                                                  (globals()[tag_dict['source']]['datetime'] <= tag_dict['source_training_to']) ]

globals()[tag_dict['target']+'_training'] = globals()[tag_dict['target']][
                                                  (globals()[tag_dict['target']]['datetime'] > tag_dict['target_training_from']) &
                                                  (globals()[tag_dict['target']]['datetime'] <= tag_dict['target_training_to']) ]

# %%
drop_list = ['Unnamed: 0', '_id','type','scada','timestamp','device', 'datetime']

globals()[tag_dict['source']+'_training'] = globals()[tag_dict['source']+'_training'].drop(columns=drop_list)
globals()[tag_dict['target']+'_training'] = globals()[tag_dict['target']+'_training'].drop(columns=drop_list)

# %%
shape_min = min (globals()[tag_dict['source']+'_training'].shape[0], 
                 globals()[tag_dict['target']+'_training'].shape[0])
shape_max = max (globals()[tag_dict['source']+'_training'].shape[0], 
                 globals()[tag_dict['target']+'_training'].shape[0])

index = sorted(random.sample(range(0, shape_max), shape_min))

# %%
normalizer = preprocessing.MinMaxScaler()
normalizer = normalizer.fit(globals()[tag_dict['source']+'_training'])

X_source = pd.DataFrame(normalizer.transform(globals()[tag_dict['source']+'_training']))
X_target = pd.DataFrame(normalizer.transform(globals()[tag_dict['target']+'_training']))

# %%
def temporalize(X, y, lookback):
    output_X = []
    output_y = []
    for i in range(len(X)-lookback-1):
        t = []
        for j in range(1,lookback+1):
            # Gather past records upto the lookback period
            t.append(X[[(i+j+1)], :])
        output_X.append(t)
        output_y.append(y[i+lookback+1])
    return output_X, output_y

# %%
if len(X_target) > len(X_source):
    X = X_target.iloc[index]
    Y = X_source
else:
    X = X_target
    Y = X_source.iloc[index]


timesteps = 4
n_features = 390

#X, y = temporalize(X = timeseries, y = np.zeros(len(timeseries)), lookback = timesteps)
X, _ = temporalize(X = X.values, y = np.zeros(len(X)), lookback = timesteps)
Y, _ = temporalize(X = Y.values, y = np.zeros(len(Y)), lookback = timesteps)

X = np.array(X)
X = X.reshape(X.shape[0], timesteps, n_features)

Y = np.array(Y)
Y = Y.reshape(np.array(Y).shape[0], timesteps, n_features)

# %% [markdown]
# # LSTM-AE Model

# %%
def lstm_ae():
    # define model
    model = Sequential()
    model.add(LSTM(64, activation='relu', input_shape=(timesteps,n_features), return_sequences=True))
    model.add(LSTM(16, activation='relu', return_sequences=False))
    model.add(RepeatVector(timesteps))
    model.add(LSTM(16, activation='relu', return_sequences=True))
    model.add(LSTM(64, activation='relu', return_sequences=True))
    model.add(TimeDistributed(Dense(n_features)))
    model.compile(optimizer='adam', loss='mse', metrics=[metrics.RootMeanSquaredError()])
    model.summary()

    return model

# %%
model_name = './gdrive/My Drive/data/CSC/W4/' + tag_dict['target'] + '_encoded'
model_name
# Out:
# './gdrive/My Drive/data/CSC/W4/W4662FM0400_encoded'

# %%
retrain = True


if retrain:
    early_stopping = EarlyStopping(monitor='val_loss', patience=150, verbose=2)

    model = lstm_ae ()
    lstm_ae_model = model.fit(Y, X, epochs=150, batch_size=16, verbose=1, validation_split=0.2, callbacks=[early_stopping])
    model.save(model_name)
else:
    model = models.load_model(model_name)  
    

#model = models.load_model(model_name)    
synthetic_data = model.predict(X, verbose=0)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 4, 64)             116480
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 16)                5184
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 4, 16)             0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 4, 16)             2112
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 4, 64)             20736
# _________________________________________________________________
# time_distributed (TimeDistri (None, 4, 390)            25350
# =================================================================
# Total params: 169,862
# Trainable params: 169,862
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/150
# 2584/2584 [==============================] - 36s 12ms/step - loss: 0.0302 - root_mean_squared_error: 0.1577 - val_loss: 0.0091 - val_root_mean_squared_error: 0.0956
# Epoch 2/150
# 2584/2584 [==============================] - 31s 12ms/step - loss: 0.0103 - root_mean_squared_error: 0.1015 - val_loss: 0.0091 - val_root_mean_squared_error: 0.0954
# Epoch 3/150
# 2584/2584 [==============================] - 31s 12ms/step - loss: 0.0102 - root_mean_squared_error: 0.1010 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0939
# Epoch 4/150
# 2584/2584 [==============================] - 31s 12ms/step - loss: 0.0101 - root_mean_squared_error: 0.1007 - val_loss: 0.0092 - val_root_mean_squared_error: 0.0958
# Epoch 5/150
# 2584/2584 [==============================] - 31s 12ms/step - loss: 0.0099 - root_mean_squared_error: 0.0994 - val_loss: 0.0093 - val_root_mean_squared_error: 0.0966
# Epoch 6/150
# 2584/2584 [==============================] - 31s 12ms/step - loss: 0.0095 - root_mean_squared_error: 0.0972 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0984
# Epoch 7/150
# 2584/2584 [==============================] - 31s 12ms/step - loss: 0.0092 - root_mean_squared_error: 0.0961 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0968
# Epoch 8/150
# 2584/2584 [==============================] - 31s 12ms/step - loss: 0.0091 - root_mean_squared_error: 0.0955 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0975
# Epoch 9/150
# 2584/2584 [==============================] - 31s 12ms/step - loss: 0.0090 - root_mean_squared_error: 0.0951 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0974
# Epoch 10/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0089 - root_mean_squared_error: 0.0943 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0983
# Epoch 11/150
# 2584/2584 [==============================] - 31s 12ms/step - loss: 0.0088 - root_mean_squared_error: 0.0937 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0977
# Epoch 12/150
# 2584/2584 [==============================] - 31s 12ms/step - loss: 0.0087 - root_mean_squared_error: 0.0932 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0978
# Epoch 13/150
# 2584/2584 [==============================] - 31s 12ms/step - loss: 0.0087 - root_mean_squared_error: 0.0930 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0983
# Epoch 14/150
# 2584/2584 [==============================] - 31s 12ms/step - loss: 0.0086 - root_mean_squared_error: 0.0926 - val_loss: 0.0092 - val_root_mean_squared_error: 0.0958
# Epoch 15/150
# 2584/2584 [==============================] - 31s 12ms/step - loss: 0.0085 - root_mean_squared_error: 0.0923 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0984
# Epoch 16/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0084 - root_mean_squared_error: 0.0915 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0974
# Epoch 17/150
# 2584/2584 [==============================] - 31s 12ms/step - loss: 0.0084 - root_mean_squared_error: 0.0915 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0984
# Epoch 18/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0084 - root_mean_squared_error: 0.0916 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0981
# Epoch 19/150
# 2584/2584 [==============================] - 37s 14ms/step - loss: 0.0083 - root_mean_squared_error: 0.0914 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0967
# Epoch 20/150
# 2584/2584 [==============================] - 31s 12ms/step - loss: 0.0083 - root_mean_squared_error: 0.0913 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0976
# Epoch 21/150
# 2584/2584 [==============================] - 31s 12ms/step - loss: 0.0083 - root_mean_squared_error: 0.0909 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0972
# Epoch 22/150
# 2584/2584 [==============================] - 31s 12ms/step - loss: 0.0083 - root_mean_squared_error: 0.0909 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0985
# Epoch 23/150
# 2584/2584 [==============================] - 31s 12ms/step - loss: 0.0082 - root_mean_squared_error: 0.0904 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0983
# Epoch 24/150
# 2584/2584 [==============================] - 31s 12ms/step - loss: 0.0082 - root_mean_squared_error: 0.0907 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0978
# Epoch 25/150
# 2584/2584 [==============================] - 31s 12ms/step - loss: 0.0082 - root_mean_squared_error: 0.0907 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0981
# Epoch 26/150
# 2584/2584 [==============================] - 31s 12ms/step - loss: 0.0081 - root_mean_squared_error: 0.0901 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0987
# Epoch 27/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0081 - root_mean_squared_error: 0.0902 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0981
# Epoch 28/150
# 2584/2584 [==============================] - 31s 12ms/step - loss: 0.0081 - root_mean_squared_error: 0.0899 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0978
# Epoch 29/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0080 - root_mean_squared_error: 0.0897 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0983
# Epoch 30/150
# 2584/2584 [==============================] - 31s 12ms/step - loss: 0.0081 - root_mean_squared_error: 0.0901 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0980
# Epoch 31/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0080 - root_mean_squared_error: 0.0895 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0972
# Epoch 32/150
# 2584/2584 [==============================] - 31s 12ms/step - loss: 0.0081 - root_mean_squared_error: 0.0898 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0980
# Epoch 33/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0080 - root_mean_squared_error: 0.0895 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0986
# Epoch 34/150
# 2584/2584 [==============================] - 31s 12ms/step - loss: 0.0079 - root_mean_squared_error: 0.0890 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0980
# Epoch 35/150
# 2584/2584 [==============================] - 31s 12ms/step - loss: 0.0080 - root_mean_squared_error: 0.0895 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0982
# Epoch 36/150
# 2584/2584 [==============================] - 31s 12ms/step - loss: 0.0080 - root_mean_squared_error: 0.0892 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0976
# Epoch 37/150
# 2584/2584 [==============================] - 31s 12ms/step - loss: 0.0079 - root_mean_squared_error: 0.0889 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0977
# Epoch 38/150
# 2584/2584 [==============================] - 31s 12ms/step - loss: 0.0079 - root_mean_squared_error: 0.0889 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0975
# Epoch 39/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0080 - root_mean_squared_error: 0.0894 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0978
# Epoch 40/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0079 - root_mean_squared_error: 0.0887 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0975
# Epoch 41/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0079 - root_mean_squared_error: 0.0890 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0980
# Epoch 42/150
# 2584/2584 [==============================] - 37s 14ms/step - loss: 0.0079 - root_mean_squared_error: 0.0889 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0973
# Epoch 43/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0079 - root_mean_squared_error: 0.0888 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0987
# Epoch 44/150
# 2584/2584 [==============================] - 31s 12ms/step - loss: 0.0078 - root_mean_squared_error: 0.0885 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0992
# Epoch 45/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0078 - root_mean_squared_error: 0.0885 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0976
# Epoch 46/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0078 - root_mean_squared_error: 0.0883 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0978
# Epoch 47/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0078 - root_mean_squared_error: 0.0882 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0988
# Epoch 48/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0078 - root_mean_squared_error: 0.0884 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0974
# Epoch 49/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0078 - root_mean_squared_error: 0.0883 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0982
# Epoch 50/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0077 - root_mean_squared_error: 0.0880 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0989
# Epoch 51/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0077 - root_mean_squared_error: 0.0879 - val_loss: 0.0102 - val_root_mean_squared_error: 0.1011
# Epoch 52/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0078 - root_mean_squared_error: 0.0884 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0996
# Epoch 53/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0078 - root_mean_squared_error: 0.0883 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0996
# Epoch 54/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0078 - root_mean_squared_error: 0.0881 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0989
# Epoch 55/150
# 2584/2584 [==============================] - 31s 12ms/step - loss: 0.0077 - root_mean_squared_error: 0.0880 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0983
# Epoch 56/150
# 2584/2584 [==============================] - 33s 13ms/step - loss: 0.0078 - root_mean_squared_error: 0.0882 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0996
# Epoch 57/150
# 2584/2584 [==============================] - 31s 12ms/step - loss: 0.0077 - root_mean_squared_error: 0.0879 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0982
# Epoch 58/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0078 - root_mean_squared_error: 0.0883 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0978
# Epoch 59/150
# 2584/2584 [==============================] - 31s 12ms/step - loss: 0.0077 - root_mean_squared_error: 0.0879 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0994
# Epoch 60/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0078 - root_mean_squared_error: 0.0881 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0997
# Epoch 61/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0077 - root_mean_squared_error: 0.0876 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0940
# Epoch 62/150
# 2584/2584 [==============================] - 31s 12ms/step - loss: 0.0090 - root_mean_squared_error: 0.0948 - val_loss: 0.0093 - val_root_mean_squared_error: 0.0965
# Epoch 63/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0085 - root_mean_squared_error: 0.0922 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0971
# Epoch 64/150
# 2584/2584 [==============================] - 31s 12ms/step - loss: 0.0084 - root_mean_squared_error: 0.0914 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0977
# Epoch 65/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0082 - root_mean_squared_error: 0.0904 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0977
# Epoch 66/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0081 - root_mean_squared_error: 0.0901 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0970
# Epoch 67/150
# 2584/2584 [==============================] - 31s 12ms/step - loss: 0.0081 - root_mean_squared_error: 0.0897 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0971
# Epoch 68/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0080 - root_mean_squared_error: 0.0895 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0975
# Epoch 69/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0080 - root_mean_squared_error: 0.0894 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0971
# Epoch 70/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0080 - root_mean_squared_error: 0.0892 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0978
# Epoch 71/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0081 - root_mean_squared_error: 0.0900 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0968
# Epoch 72/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0079 - root_mean_squared_error: 0.0890 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0974
# Epoch 73/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0079 - root_mean_squared_error: 0.0888 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0968
# Epoch 74/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0078 - root_mean_squared_error: 0.0884 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0978
# Epoch 75/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0078 - root_mean_squared_error: 0.0886 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0989
# Epoch 76/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0079 - root_mean_squared_error: 0.0887 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0988
# Epoch 77/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0078 - root_mean_squared_error: 0.0885 - val_loss: 0.0100 - val_root_mean_squared_error: 0.0998
# Epoch 78/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0078 - root_mean_squared_error: 0.0881 - val_loss: 0.0100 - val_root_mean_squared_error: 0.0999
# Epoch 79/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0078 - root_mean_squared_error: 0.0882 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1014
# Epoch 80/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0078 - root_mean_squared_error: 0.0885 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0994
# Epoch 81/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0078 - root_mean_squared_error: 0.0880 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0987
# Epoch 82/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0077 - root_mean_squared_error: 0.0880 - val_loss: 0.0100 - val_root_mean_squared_error: 0.1000
# Epoch 83/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0077 - root_mean_squared_error: 0.0876 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0996
# Epoch 84/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0077 - root_mean_squared_error: 0.0878 - val_loss: 0.0102 - val_root_mean_squared_error: 0.1012
# Epoch 85/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0076 - root_mean_squared_error: 0.0874 - val_loss: 0.0102 - val_root_mean_squared_error: 0.1010
# Epoch 86/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0077 - root_mean_squared_error: 0.0876 - val_loss: 0.0102 - val_root_mean_squared_error: 0.1010
# Epoch 87/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0077 - root_mean_squared_error: 0.0875 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1013
# Epoch 88/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0077 - root_mean_squared_error: 0.0877 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1016
# Epoch 89/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0076 - root_mean_squared_error: 0.0874 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0983
# Epoch 90/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0076 - root_mean_squared_error: 0.0874 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0996
# Epoch 91/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0077 - root_mean_squared_error: 0.0876 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0990
# Epoch 92/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0076 - root_mean_squared_error: 0.0873 - val_loss: 0.0100 - val_root_mean_squared_error: 0.1000
# Epoch 93/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0077 - root_mean_squared_error: 0.0875 - val_loss: 0.0100 - val_root_mean_squared_error: 0.1002
# Epoch 94/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0076 - root_mean_squared_error: 0.0870 - val_loss: 0.0101 - val_root_mean_squared_error: 0.1003
# Epoch 95/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0076 - root_mean_squared_error: 0.0871 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1017
# Epoch 96/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0076 - root_mean_squared_error: 0.0874 - val_loss: 0.0101 - val_root_mean_squared_error: 0.1005
# Epoch 97/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0075 - root_mean_squared_error: 0.0867 - val_loss: 0.0100 - val_root_mean_squared_error: 0.0999
# Epoch 98/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0076 - root_mean_squared_error: 0.0870 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0983
# Epoch 99/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0077 - root_mean_squared_error: 0.0876 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0993
# Epoch 100/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0076 - root_mean_squared_error: 0.0871 - val_loss: 0.0101 - val_root_mean_squared_error: 0.1006
# Epoch 101/150
# 2584/2584 [==============================] - 33s 13ms/step - loss: 0.0076 - root_mean_squared_error: 0.0872 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0980
# Epoch 102/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0076 - root_mean_squared_error: 0.0869 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0995
# Epoch 103/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0076 - root_mean_squared_error: 0.0872 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0997
# Epoch 104/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0076 - root_mean_squared_error: 0.0871 - val_loss: 0.0102 - val_root_mean_squared_error: 0.1011
# Epoch 105/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0075 - root_mean_squared_error: 0.0866 - val_loss: 0.0100 - val_root_mean_squared_error: 0.0999
# Epoch 106/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0076 - root_mean_squared_error: 0.0870 - val_loss: 0.0101 - val_root_mean_squared_error: 0.1007
# Epoch 107/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0076 - root_mean_squared_error: 0.0869 - val_loss: 0.0101 - val_root_mean_squared_error: 0.1007
# Epoch 108/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0075 - root_mean_squared_error: 0.0865 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0979
# Epoch 109/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0075 - root_mean_squared_error: 0.0867 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0992
# Epoch 110/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0075 - root_mean_squared_error: 0.0864 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0994
# Epoch 111/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0075 - root_mean_squared_error: 0.0867 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0982
# Epoch 112/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0075 - root_mean_squared_error: 0.0868 - val_loss: 0.0101 - val_root_mean_squared_error: 0.1006
# Epoch 113/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0075 - root_mean_squared_error: 0.0868 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0988
# Epoch 114/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0075 - root_mean_squared_error: 0.0868 - val_loss: 0.0101 - val_root_mean_squared_error: 0.1003
# Epoch 115/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0075 - root_mean_squared_error: 0.0866 - val_loss: 0.0102 - val_root_mean_squared_error: 0.1011
# Epoch 116/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0075 - root_mean_squared_error: 0.0864 - val_loss: 0.0100 - val_root_mean_squared_error: 0.1002
# Epoch 117/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0074 - root_mean_squared_error: 0.0862 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0994
# Epoch 118/150
# 2584/2584 [==============================] - 33s 13ms/step - loss: 0.0075 - root_mean_squared_error: 0.0864 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0975
# Epoch 119/150
# 2584/2584 [==============================] - 32s 13ms/step - loss: 0.0075 - root_mean_squared_error: 0.0866 - val_loss: 0.0100 - val_root_mean_squared_error: 0.1002
# Epoch 120/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0075 - root_mean_squared_error: 0.0866 - val_loss: 0.0100 - val_root_mean_squared_error: 0.0998
# Epoch 121/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0075 - root_mean_squared_error: 0.0865 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1015
# Epoch 122/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0075 - root_mean_squared_error: 0.0866 - val_loss: 0.0101 - val_root_mean_squared_error: 0.1006
# Epoch 123/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0075 - root_mean_squared_error: 0.0866 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0972
# Epoch 124/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0077 - root_mean_squared_error: 0.0878 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0990
# Epoch 125/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0074 - root_mean_squared_error: 0.0861 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0996
# Epoch 126/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0075 - root_mean_squared_error: 0.0867 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0986
# Epoch 127/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0074 - root_mean_squared_error: 0.0862 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0985
# Epoch 128/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0074 - root_mean_squared_error: 0.0859 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0990
# Epoch 129/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0082 - root_mean_squared_error: 0.0905 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0979
# Epoch 130/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0075 - root_mean_squared_error: 0.0863 - val_loss: 0.0101 - val_root_mean_squared_error: 0.1004
# Epoch 131/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0075 - root_mean_squared_error: 0.0865 - val_loss: 0.0100 - val_root_mean_squared_error: 0.1000
# Epoch 132/150
# 2584/2584 [==============================] - 32s 12ms/step - loss: 0.0075 - root_mean_squared_error: 0.0864 - val_loss: 0.0100 - val_root_mean_squared_error: 0.1000
# Epoch 133/150
# 2584/2584 [==============================] - 32s 13ms/step - loss: 0.0074 - root_mean_squared_error: 0.0859 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0994
# Epoch 134/150
# 2584/2584 [==============================] - 32s 13ms/step - loss: 0.0074 - root_mean_squared_error: 0.0861 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0984
# Epoch 135/150
# 2584/2584 [==============================] - 33s 13ms/step - loss: 0.0074 - root_mean_squared_error: 0.0859 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0986
# Epoch 136/150
# 2584/2584 [==============================] - 33s 13ms/step - loss: 0.0075 - root_mean_squared_error: 0.0865 - val_loss: 0.0100 - val_root_mean_squared_error: 0.1002
# Epoch 137/150
# 2584/2584 [==============================] - 33s 13ms/step - loss: 0.0074 - root_mean_squared_error: 0.0861 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0982
# Epoch 138/150
# 2584/2584 [==============================] - 32s 13ms/step - loss: 0.0074 - root_mean_squared_error: 0.0861 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0991
# Epoch 139/150
# 2584/2584 [==============================] - 32s 13ms/step - loss: 0.0074 - root_mean_squared_error: 0.0863 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0985
# Epoch 140/150
# 2584/2584 [==============================] - 32s 13ms/step - loss: 0.0075 - root_mean_squared_error: 0.0865 - val_loss: 0.0101 - val_root_mean_squared_error: 0.1006
# Epoch 141/150
# 2584/2584 [==============================] - 32s 13ms/step - loss: 0.0074 - root_mean_squared_error: 0.0860 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0989
# Epoch 142/150
# 2584/2584 [==============================] - 33s 13ms/step - loss: 0.0083 - root_mean_squared_error: 0.0913 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0970
# Epoch 143/150
# 2584/2584 [==============================] - 32s 13ms/step - loss: 0.0083 - root_mean_squared_error: 0.0910 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0974
# Epoch 144/150
# 2584/2584 [==============================] - 33s 13ms/step - loss: 0.0081 - root_mean_squared_error: 0.0900 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0984
# Epoch 145/150
# 2584/2584 [==============================] - 33s 13ms/step - loss: 0.0081 - root_mean_squared_error: 0.0899 - val_loss: 0.0110 - val_root_mean_squared_error: 0.1048
# Epoch 146/150
# 2584/2584 [==============================] - 34s 13ms/step - loss: 0.0076 - root_mean_squared_error: 0.0871 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0986
# Epoch 147/150
# 2584/2584 [==============================] - 33s 13ms/step - loss: 0.0075 - root_mean_squared_error: 0.0868 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0980
# Epoch 148/150
# 2584/2584 [==============================] - 32s 13ms/step - loss: 0.0076 - root_mean_squared_error: 0.0869 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0997
# Epoch 149/150
# 2584/2584 [==============================] - 33s 13ms/step - loss: 0.0075 - root_mean_squared_error: 0.0863 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0984
# Epoch 150/150
# 2584/2584 [==============================] - 33s 13ms/step - loss: 0.0075 - root_mean_squared_error: 0.0866 - val_loss: 0.0101 - val_root_mean_squared_error: 0.1004
# INFO:tensorflow:Assets written to: ./gdrive/My Drive/data/CSC/W4/W4662FM0400_encoded/assets

# %%
if retrain:
    fig, ax = plt.subplots(figsize=(10,5))

    ax.plot(lstm_ae_model.history['loss'], marker='.', label='loss')
    ax.plot(lstm_ae_model.history['val_loss'], marker='.', label='validation loss')

    ax.legend()
    ax.grid(True)

    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.savefig('epoches.png', dpi=300)
    plt.show()

# %%
synthetic_pd = pd.DataFrame.from_records([i[0] for i in synthetic_data])

# %% [markdown]
# # Validation

# %% [markdown]
# ## PCA

# %%
from sklearn.decomposition import PCA

pca_scale = PCA(n_components=2)
pca_scale = pca_scale.fit(X_source)

X_source_dr = pca_scale.transform(X_source)
x_min, x_max = X_source_dr.min(0), X_source_dr.max(0)
X_norm = (X_source_dr-x_min) / (x_max-x_min)  #Normalize
X_source_df = pd.DataFrame(X_norm, columns = ['dim1','dim2'])

X_target_dr = pca_scale.transform(X_target)
x_min, x_max = X_target_dr.min(0), X_target_dr.max(0)
X_norm = (X_target_dr-x_min) / (x_max-x_min)  #Normalize
X_target_df = pd.DataFrame(X_norm, columns = ['dim1','dim2'])

X_decoder_dr = pca_scale.transform(synthetic_pd)
x_min, x_max = X_decoder_dr.min(0), X_decoder_dr.max(0)
X_norm = (X_decoder_dr-x_min) / (x_max-x_min)  #Normalize
X_decode_df = pd.DataFrame(X_norm, columns = ['dim1','dim2'])

# %%
fig, ax = plt.subplots(figsize=(10,5))

ax.scatter(X_source_df['dim1'], X_source_df['dim2'], alpha=0.1, label='source')
ax.scatter(X_target_df['dim1'], X_target_df['dim2'], alpha=0.1, label='target')
ax.scatter(X_decode_df['dim1'], X_decode_df['dim2'], alpha=0.1, label='decode')

ax.legend()
ax.grid(True)

#plt.ylim(0, 1)
#plt.xlim(0, 1)
plt.savefig('distribution.png', dpi=300)
plt.show()

# %% [markdown]
# ## Model Cross Validation

# %%
model_source = svm.OneClassSVM(nu=0.01, kernel="rbf", gamma=0.01).fit(X_source)
model_target = svm.OneClassSVM(nu=0.01, kernel="rbf", gamma=0.01).fit(X_target)
model_synthetic = svm.OneClassSVM(nu=0.01, kernel="rbf", gamma=0.01).fit(synthetic_pd)

# %%
def scorer_(Y_pred):
    a = (Y_pred[Y_pred == -1].size)/(Y_pred.size)
    return a*100

# %%
def plot_score (score_list, date_list, tag):

    fig, ax = plt.subplots(figsize=(10, 3))
    plt.xticks(rotation=45)
    ax.plot(date_list, score_list, '.-')
    ax.set(xlabel='date', ylabel='score', title=tag)
    ax.grid()
    plt.ylim(0, 100)
    plt.tight_layout()
    #fig.savefig(path+tag+'-'+training_from.strftime("%Y%m%d")+'-'+training_to.strftime("%Y%m%d")+'.png', dpi=300)
    plt.show()

# %%
def get_score (data_df, start_date, end_date, normalizer, prediction_model):

    score_list = []
    date_list = []
    delta = datetime.timedelta(days=1)

    while start_date <= end_date:

        validation_df = data_df[(data_df['datetime'] > start_date) & 
                                (data_df['datetime'] <= start_date + delta)]

        
        if len(validation_df) > 0:

            validation_df_score = validation_df.drop(columns=drop_list)
            validation_df_score = normalizer.transform(validation_df_score)
            validation_df_score = prediction_model.predict(validation_df_score)

            score_list.append(scorer_(validation_df_score))
            date_list.append(start_date)

        start_date += delta
        
    return score_list, date_list

# %%
target_score_cv, target_date_cv = get_score(globals()[tag_dict['target']], 
                                            tag_dict['target_training_from'], 
                                            tag_dict['target_end'], 
                                            normalizer,
                                            model_source)

target_score, target_date = get_score(globals()[tag_dict['target']], 
                                            tag_dict['target_training_from'], 
                                            tag_dict['target_end'], 
                                            normalizer,
                                            model_target)

target_score_da, target_date_da = get_score(globals()[tag_dict['target']], 
                                            tag_dict['target_training_from'], 
                                            tag_dict['target_end'], 
                                            normalizer,
                                            model_synthetic)

# %%
def rmse(predictions, targets):
    return np.sqrt(((predictions - targets) ** 2).mean())

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(target_score_cv, target_score, squared=False)
# Out:
# 19.506953748108696

# %%
da_rmse = mean_squared_error(target_score_da, target_score, squared=False)
cv_rmse = mean_squared_error(target_score_cv, target_score, squared=False)



plot_score (target_score, target_date, 'Detect ' + tag_dict['target'] +' conditions by using '+ tag_dict['target'] +' model')

plot_score (target_score_cv, 
            target_date_cv, 
            'Detect ' + tag_dict['target'] +' conditions by using '+ tag_dict['source'] +' model, RMSE='+ "{:.3f}".format(cv_rmse))

plot_score (target_score_da, 
            target_date_da, 
            'Detect ' + tag_dict['target'] +' conditions by using '+ tag_dict['source'] +' synthetic model, RMSE=' + "{:.3f}".format(da_rmse))

# %% [markdown]
# ## Check Synthetic Data

# %%
feature_index = 206
duration = 26000
interval = 100
fig, ax = plt.subplots(figsize=(10,5))

ax.plot(range(duration, duration+interval), X_target[feature_index].head(duration).tail(interval), label='target', marker='.')
ax.plot(range(duration, duration+interval), X_source[feature_index].head(duration).tail(interval), label='source', marker='.')
ax.plot(range(duration, duration+interval), synthetic_pd[feature_index].head(duration).tail(interval), label='synthetic', marker='.')

ax.legend()
ax.grid(True)
plt.tight_layout()

#plt.savefig('distribution.png', dpi=300)
plt.show()
