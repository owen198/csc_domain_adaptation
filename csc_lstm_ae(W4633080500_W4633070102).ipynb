# %% [markdown]
# <a href="https://colab.research.google.com/github/owen198/csc_domain_adaptation/blob/main/csc_lstm_ae(W4633080500_W4633070102).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# https://towardsdatascience.com/step-by-step-understanding-lstm-autoencoder-layers-ffab055b6352

from sklearn import preprocessing
from sklearn import svm
import pandas as pd
import datetime

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import random


from keras import metrics
from keras import models
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from keras.layers import Input, BatchNormalization, Activation
from keras.callbacks import EarlyStopping

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot

# %% [markdown]
# # Load Data and proprecessing

# %%
tag_dict = {'target':'W4633070102',
            'target_training_from': datetime.datetime(2018,9,1,0,0),
            'target_training_to': datetime.datetime(2018,12,1,0,0),
            'target_end': datetime.datetime(2019,3,1,0,0),
            
            'source':'W4633080500',
            'source_training_from': datetime.datetime(2018,9,1,0,0),
            'source_training_to': datetime.datetime(2018,12,1,0,0),
            'source_end': datetime.datetime(2019,3,1,0,0)}

path = './gdrive/MyDrive/data/CSC/W4/'

# %%
globals()[tag_dict['source']] = pd.concat([pd.read_csv(path + tag_dict['source'] + '_201809.csv'),
                                          pd.read_csv(path + tag_dict['source'] + '_201810.csv'),
                                          pd.read_csv(path + tag_dict['source'] + '_201811.csv'),
                                          pd.read_csv(path + tag_dict['source'] + '_201812.csv'),
                                          pd.read_csv(path + tag_dict['source'] + '_201901.csv'),
                                          pd.read_csv(path + tag_dict['source'] + '_201902.csv'),
                                          pd.read_csv(path + tag_dict['source'] + '_201903.csv')])

globals()[tag_dict['target']] = pd.concat([pd.read_csv(path + tag_dict['target'] + '_201809.csv'),
                                          pd.read_csv(path + tag_dict['target'] + '_201810.csv'),
                                          pd.read_csv(path + tag_dict['target'] + '_201811.csv'),
                                          pd.read_csv(path + tag_dict['target'] + '_201812.csv'),
                                          pd.read_csv(path + tag_dict['target'] + '_201901.csv'),
                                          pd.read_csv(path + tag_dict['target'] + '_201902.csv'),
                                          pd.read_csv(path + tag_dict['target'] + '_201903.csv')])

# %%
globals()[tag_dict['source']]['datetime'] = globals()[tag_dict['source']]['timestamp'].astype('int').astype("datetime64[s]")
globals()[tag_dict['target']]['datetime'] = globals()[tag_dict['target']]['timestamp'].astype('int').astype("datetime64[s]")

# %%
globals()[tag_dict['source']+'_training'] = globals()[tag_dict['source']][
                                                  (globals()[tag_dict['source']]['datetime'] > tag_dict['source_training_from']) &
                                                  (globals()[tag_dict['source']]['datetime'] <= tag_dict['source_training_to']) ]

globals()[tag_dict['target']+'_training'] = globals()[tag_dict['target']][
                                                  (globals()[tag_dict['target']]['datetime'] > tag_dict['target_training_from']) &
                                                  (globals()[tag_dict['target']]['datetime'] <= tag_dict['target_training_to']) ]

# %%
drop_list = ['Unnamed: 0', '_id','type','scada','timestamp','device', 'datetime']

globals()[tag_dict['source']+'_training'] = globals()[tag_dict['source']+'_training'].drop(columns=drop_list)
globals()[tag_dict['target']+'_training'] = globals()[tag_dict['target']+'_training'].drop(columns=drop_list)

# %%
shape_min = min (globals()[tag_dict['source']+'_training'].shape[0], 
                 globals()[tag_dict['target']+'_training'].shape[0])
shape_max = max (globals()[tag_dict['source']+'_training'].shape[0], 
                 globals()[tag_dict['target']+'_training'].shape[0])

index = sorted(random.sample(range(0, shape_max), shape_min))

# %%
normalizer = preprocessing.MinMaxScaler()
normalizer = normalizer.fit(globals()[tag_dict['source']+'_training'])

X_source = pd.DataFrame(normalizer.transform(globals()[tag_dict['source']+'_training']))
X_target = pd.DataFrame(normalizer.transform(globals()[tag_dict['target']+'_training']))

# %%
def temporalize(X, y, lookback):
    output_X = []
    output_y = []
    for i in range(len(X)-lookback-1):
        t = []
        for j in range(1,lookback+1):
            # Gather past records upto the lookback period
            t.append(X[[(i+j+1)], :])
        output_X.append(t)
        output_y.append(y[i+lookback+1])
    return output_X, output_y

# %%
if len(X_target) > len(X_source):
    X = X_target.iloc[index]
    Y = X_source
else:
    X = X_target
    Y = X_source.iloc[index]


timesteps = 16
n_features = 390

#X, y = temporalize(X = timeseries, y = np.zeros(len(timeseries)), lookback = timesteps)
X, _ = temporalize(X = X.values, y = np.zeros(len(X)), lookback = timesteps)
Y, _ = temporalize(X = Y.values, y = np.zeros(len(Y)), lookback = timesteps)

X = np.array(X)
X = X.reshape(X.shape[0], timesteps, n_features)

Y = np.array(Y)
Y = Y.reshape(np.array(Y).shape[0], timesteps, n_features)

# %% [markdown]
# # LSTM-AE Model

# %%
def lstm_ae():
    # define model
    model = Sequential()
    model.add(LSTM(64, activation='relu', input_shape=(timesteps,n_features), return_sequences=True))
    model.add(LSTM(16, activation='relu', return_sequences=False))
    model.add(RepeatVector(timesteps))
    model.add(LSTM(16, activation='relu', return_sequences=True))
    model.add(LSTM(64, activation='relu', return_sequences=True))
    model.add(TimeDistributed(Dense(n_features)))
    model.compile(optimizer='adam', loss='mse', metrics=[metrics.RootMeanSquaredError()])
    model.summary()

    return model

# %%
model_name = './gdrive/My Drive/data/CSC/W4/' + tag_dict['target'] + '_encoded'
model_name
# Out:
# './gdrive/My Drive/data/CSC/W4/W4633070102_encoded'

# %%
retrain = True


if retrain:
    early_stopping = EarlyStopping(monitor='val_loss', patience=150, verbose=2)

    model = lstm_ae ()
    lstm_ae_model = model.fit(Y, X, epochs=150, batch_size=16, verbose=1, validation_split=0.2, callbacks=[early_stopping])
    model.save(model_name)

    
else:
    model = models.load_model(model_name)  

SVG(model_to_dot(model).create(prog='dot', format='svg'))
    

#model = models.load_model(model_name)    
synthetic_data = model.predict(X, verbose=0)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 16, 64)            116480
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 16)                5184
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 16, 16)            0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 16, 16)            2112
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 16, 64)            20736
# _________________________________________________________________
# time_distributed (TimeDistri (None, 16, 390)           25350
# =================================================================
# Total params: 169,862
# Trainable params: 169,862
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/150
# 673/673 [==============================] - 41s 40ms/step - loss: 0.0054 - root_mean_squared_error: 0.0692 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0406
# Epoch 2/150
# 673/673 [==============================] - 24s 36ms/step - loss: 0.0017 - root_mean_squared_error: 0.0412 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0403
# Epoch 3/150
# 673/673 [==============================] - 24s 36ms/step - loss: 0.0017 - root_mean_squared_error: 0.0407 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0406
# Epoch 4/150
# 673/673 [==============================] - 24s 35ms/step - loss: 0.0017 - root_mean_squared_error: 0.0407 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0403
# Epoch 5/150
# 673/673 [==============================] - 23s 35ms/step - loss: 0.0016 - root_mean_squared_error: 0.0406 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0405
# Epoch 6/150
# 673/673 [==============================] - 23s 35ms/step - loss: 0.0016 - root_mean_squared_error: 0.0404 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0401
# Epoch 7/150
# 673/673 [==============================] - 23s 35ms/step - loss: 0.0016 - root_mean_squared_error: 0.0405 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0403
# Epoch 8/150
# 673/673 [==============================] - 23s 35ms/step - loss: 0.0016 - root_mean_squared_error: 0.0404 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0404
# Epoch 9/150
# 673/673 [==============================] - 24s 36ms/step - loss: 0.0016 - root_mean_squared_error: 0.0403 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0403
# Epoch 10/150
# 673/673 [==============================] - 24s 36ms/step - loss: 0.0016 - root_mean_squared_error: 0.0402 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0402
# Epoch 11/150
# 673/673 [==============================] - 24s 35ms/step - loss: 0.0016 - root_mean_squared_error: 0.0401 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0402
# Epoch 12/150
# 673/673 [==============================] - 24s 35ms/step - loss: 0.0016 - root_mean_squared_error: 0.0401 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0404
# Epoch 13/150
# 673/673 [==============================] - 24s 35ms/step - loss: 0.0016 - root_mean_squared_error: 0.0401 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0402
# Epoch 14/150
# 673/673 [==============================] - 24s 36ms/step - loss: 0.0016 - root_mean_squared_error: 0.0400 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0405
# Epoch 15/150
# 673/673 [==============================] - 24s 36ms/step - loss: 0.0016 - root_mean_squared_error: 0.0401 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0403
# Epoch 16/150
# 673/673 [==============================] - 24s 35ms/step - loss: 0.0016 - root_mean_squared_error: 0.0399 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0403
# Epoch 17/150
# 673/673 [==============================] - 24s 35ms/step - loss: 0.0016 - root_mean_squared_error: 0.0400 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0401
# Epoch 18/150
# 673/673 [==============================] - 24s 36ms/step - loss: 0.0016 - root_mean_squared_error: 0.0399 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0404
# Epoch 19/150
# 673/673 [==============================] - 24s 35ms/step - loss: 0.0016 - root_mean_squared_error: 0.0398 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0408
# Epoch 20/150
# 673/673 [==============================] - 24s 35ms/step - loss: 0.0016 - root_mean_squared_error: 0.0398 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0409
# Epoch 21/150
# 673/673 [==============================] - 24s 35ms/step - loss: 0.0016 - root_mean_squared_error: 0.0398 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0404
# Epoch 22/150
# 673/673 [==============================] - 24s 35ms/step - loss: 0.0016 - root_mean_squared_error: 0.0397 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0405
# Epoch 23/150
# 673/673 [==============================] - 24s 35ms/step - loss: 0.0016 - root_mean_squared_error: 0.0397 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0402
# Epoch 24/150
# 673/673 [==============================] - 23s 35ms/step - loss: 0.0016 - root_mean_squared_error: 0.0397 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0403
# Epoch 25/150
# 673/673 [==============================] - 24s 35ms/step - loss: 0.0016 - root_mean_squared_error: 0.0396 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0401
# Epoch 26/150
# 673/673 [==============================] - 23s 35ms/step - loss: 0.0016 - root_mean_squared_error: 0.0396 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0403
# Epoch 27/150
# 673/673 [==============================] - 23s 35ms/step - loss: 0.0016 - root_mean_squared_error: 0.0396 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0402
# Epoch 28/150
# 673/673 [==============================] - 23s 35ms/step - loss: 0.0016 - root_mean_squared_error: 0.0395 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0405
# Epoch 29/150
# 673/673 [==============================] - 23s 34ms/step - loss: 0.0016 - root_mean_squared_error: 0.0395 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0403
# Epoch 30/150
# 673/673 [==============================] - 23s 34ms/step - loss: 0.0016 - root_mean_squared_error: 0.0394 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0409
# Epoch 31/150
# 673/673 [==============================] - 24s 35ms/step - loss: 0.0016 - root_mean_squared_error: 0.0395 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0405
# Epoch 32/150
# 673/673 [==============================] - 23s 35ms/step - loss: 0.0016 - root_mean_squared_error: 0.0395 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0404
# Epoch 33/150
# 673/673 [==============================] - 24s 35ms/step - loss: 0.0016 - root_mean_squared_error: 0.0394 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0408
# Epoch 34/150
# 673/673 [==============================] - 24s 35ms/step - loss: 0.0016 - root_mean_squared_error: 0.0394 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0405
# Epoch 35/150
# 673/673 [==============================] - 24s 36ms/step - loss: 0.0015 - root_mean_squared_error: 0.0392 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0405
# Epoch 36/150
# 673/673 [==============================] - 25s 37ms/step - loss: 0.0015 - root_mean_squared_error: 0.0393 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0406
# Epoch 37/150
# 673/673 [==============================] - 25s 37ms/step - loss: 0.0015 - root_mean_squared_error: 0.0392 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0412
# Epoch 38/150
# 673/673 [==============================] - 25s 37ms/step - loss: 0.0015 - root_mean_squared_error: 0.0393 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0406
# Epoch 39/150
# 673/673 [==============================] - 25s 36ms/step - loss: 0.0015 - root_mean_squared_error: 0.0392 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0406
# Epoch 40/150
# 673/673 [==============================] - 25s 37ms/step - loss: 0.0015 - root_mean_squared_error: 0.0391 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0404
# Epoch 41/150
# 673/673 [==============================] - 25s 37ms/step - loss: 0.0016 - root_mean_squared_error: 0.0394 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0407
# Epoch 42/150
# 673/673 [==============================] - 25s 36ms/step - loss: 0.0015 - root_mean_squared_error: 0.0391 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0405
# Epoch 43/150
# 673/673 [==============================] - 24s 36ms/step - loss: 0.0015 - root_mean_squared_error: 0.0391 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0406
# Epoch 44/150
# 673/673 [==============================] - 24s 36ms/step - loss: 0.0015 - root_mean_squared_error: 0.0390 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0404
# Epoch 45/150
# 673/673 [==============================] - 24s 36ms/step - loss: 0.0015 - root_mean_squared_error: 0.0391 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0408
# Epoch 46/150
# 673/673 [==============================] - 25s 37ms/step - loss: 0.0015 - root_mean_squared_error: 0.0391 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0406
# Epoch 47/150
# 673/673 [==============================] - 25s 37ms/step - loss: 0.0015 - root_mean_squared_error: 0.0390 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0406
# Epoch 48/150
# 673/673 [==============================] - 25s 37ms/step - loss: 0.0015 - root_mean_squared_error: 0.0389 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0406
# Epoch 49/150
# 673/673 [==============================] - 24s 36ms/step - loss: 0.0015 - root_mean_squared_error: 0.0389 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0407
# Epoch 50/150
# 673/673 [==============================] - 24s 36ms/step - loss: 0.0015 - root_mean_squared_error: 0.0390 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0412
# Epoch 51/150
# 673/673 [==============================] - 25s 36ms/step - loss: 0.0015 - root_mean_squared_error: 0.0389 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0409
# Epoch 52/150
# 673/673 [==============================] - 24s 36ms/step - loss: 0.0015 - root_mean_squared_error: 0.0389 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0406
# Epoch 53/150
# 673/673 [==============================] - 24s 36ms/step - loss: 0.0015 - root_mean_squared_error: 0.0388 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0408
# Epoch 54/150
# 673/673 [==============================] - 24s 36ms/step - loss: 0.0015 - root_mean_squared_error: 0.0388 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0410
# Epoch 55/150
# 673/673 [==============================] - 24s 36ms/step - loss: 0.0015 - root_mean_squared_error: 0.0388 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0406
# Epoch 56/150
# 673/673 [==============================] - 24s 36ms/step - loss: 0.0015 - root_mean_squared_error: 0.0388 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0408
# Epoch 57/150
# 673/673 [==============================] - 24s 36ms/step - loss: 0.0015 - root_mean_squared_error: 0.0388 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0405
# Epoch 58/150
# 673/673 [==============================] - 32s 47ms/step - loss: 0.0015 - root_mean_squared_error: 0.0387 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0408
# Epoch 59/150
# 673/673 [==============================] - 24s 36ms/step - loss: 0.0015 - root_mean_squared_error: 0.0388 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0409
# Epoch 60/150
# 673/673 [==============================] - 25s 36ms/step - loss: 0.0015 - root_mean_squared_error: 0.0387 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0406
# Epoch 61/150
# 673/673 [==============================] - 24s 36ms/step - loss: 0.0015 - root_mean_squared_error: 0.0387 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0407
# Epoch 62/150
# 673/673 [==============================] - 24s 36ms/step - loss: 0.0015 - root_mean_squared_error: 0.0388 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0406
# Epoch 63/150
# 673/673 [==============================] - 25s 37ms/step - loss: 0.0015 - root_mean_squared_error: 0.0386 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0409
# Epoch 64/150
# 673/673 [==============================] - 25s 37ms/step - loss: 0.0015 - root_mean_squared_error: 0.0387 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0409
# Epoch 65/150
# 673/673 [==============================] - 24s 36ms/step - loss: 0.0015 - root_mean_squared_error: 0.0386 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0408
# Epoch 66/150
# 673/673 [==============================] - 24s 36ms/step - loss: 0.0015 - root_mean_squared_error: 0.0386 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0409
# Epoch 67/150
# 673/673 [==============================] - 25s 37ms/step - loss: 0.0015 - root_mean_squared_error: 0.0386 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0407
# Epoch 68/150
# 673/673 [==============================] - 25s 37ms/step - loss: 0.0015 - root_mean_squared_error: 0.0386 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0407
# Epoch 69/150
# 673/673 [==============================] - 25s 37ms/step - loss: 0.0015 - root_mean_squared_error: 0.0386 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0409
# Epoch 70/150
# 673/673 [==============================] - 25s 37ms/step - loss: 0.0015 - root_mean_squared_error: 0.0390 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0410
# Epoch 71/150
# 673/673 [==============================] - 25s 37ms/step - loss: 0.0015 - root_mean_squared_error: 0.0385 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0411
# Epoch 72/150
# 673/673 [==============================] - 25s 37ms/step - loss: 0.0015 - root_mean_squared_error: 0.0387 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0411
# Epoch 73/150
# 673/673 [==============================] - 25s 38ms/step - loss: 0.0015 - root_mean_squared_error: 0.0385 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0410
# Epoch 74/150
# 673/673 [==============================] - 25s 37ms/step - loss: 0.0015 - root_mean_squared_error: 0.0385 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0411
# Epoch 75/150
# 673/673 [==============================] - 25s 37ms/step - loss: 0.0015 - root_mean_squared_error: 0.0385 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0408
# Epoch 76/150
# 673/673 [==============================] - 25s 37ms/step - loss: 0.0015 - root_mean_squared_error: 0.0385 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0408
# Epoch 77/150
# 673/673 [==============================] - 25s 37ms/step - loss: 0.0015 - root_mean_squared_error: 0.0385 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0411
# Epoch 78/150
# 673/673 [==============================] - 25s 36ms/step - loss: 0.0015 - root_mean_squared_error: 0.0385 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0410
# Epoch 79/150
# 673/673 [==============================] - 25s 37ms/step - loss: 0.0015 - root_mean_squared_error: 0.0385 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0410
# Epoch 80/150
# 673/673 [==============================] - 25s 37ms/step - loss: 0.0015 - root_mean_squared_error: 0.0385 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0410
# Epoch 81/150
# 673/673 [==============================] - 25s 37ms/step - loss: 0.0015 - root_mean_squared_error: 0.0385 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0408
# Epoch 82/150
# 673/673 [==============================] - 25s 37ms/step - loss: 0.0015 - root_mean_squared_error: 0.0385 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0411
# Epoch 83/150
# 673/673 [==============================] - 25s 37ms/step - loss: 0.0015 - root_mean_squared_error: 0.0385 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0409
# Epoch 84/150
# 673/673 [==============================] - 25s 37ms/step - loss: 0.0015 - root_mean_squared_error: 0.0384 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0406
# Epoch 85/150
# 673/673 [==============================] - 25s 37ms/step - loss: 0.0015 - root_mean_squared_error: 0.0385 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0407
# Epoch 86/150
# 673/673 [==============================] - 25s 37ms/step - loss: 0.0015 - root_mean_squared_error: 0.0385 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0411
# Epoch 87/150
# 673/673 [==============================] - 25s 38ms/step - loss: 0.0015 - root_mean_squared_error: 0.0384 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0410
# Epoch 88/150
# 673/673 [==============================] - 25s 38ms/step - loss: 0.0015 - root_mean_squared_error: 0.0385 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0410
# Epoch 89/150
# 673/673 [==============================] - 25s 37ms/step - loss: 0.0015 - root_mean_squared_error: 0.0384 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0411
# Epoch 90/150
# 673/673 [==============================] - 25s 37ms/step - loss: 0.0015 - root_mean_squared_error: 0.0384 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0411
# Epoch 91/150
# 673/673 [==============================] - 25s 37ms/step - loss: 0.0015 - root_mean_squared_error: 0.0385 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0410
# Epoch 92/150
# 673/673 [==============================] - 26s 38ms/step - loss: 0.0015 - root_mean_squared_error: 0.0384 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0409
# Epoch 93/150
# 673/673 [==============================] - 25s 38ms/step - loss: 0.0015 - root_mean_squared_error: 0.0384 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0411
# Epoch 94/150
# 673/673 [==============================] - 26s 38ms/step - loss: 0.0015 - root_mean_squared_error: 0.0384 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0407
# Epoch 95/150
# 673/673 [==============================] - 25s 38ms/step - loss: 0.0015 - root_mean_squared_error: 0.0384 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0411
# Epoch 96/150
# 673/673 [==============================] - 25s 38ms/step - loss: 0.0015 - root_mean_squared_error: 0.0383 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0411
# Epoch 97/150
# 673/673 [==============================] - 25s 37ms/step - loss: 0.0015 - root_mean_squared_error: 0.0383 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0412
# Epoch 98/150
# 673/673 [==============================] - 25s 37ms/step - loss: 0.0015 - root_mean_squared_error: 0.0383 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0411
# Epoch 99/150
# 673/673 [==============================] - 25s 37ms/step - loss: 0.0015 - root_mean_squared_error: 0.0383 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0411
# Epoch 100/150
# 673/673 [==============================] - 25s 37ms/step - loss: 0.0015 - root_mean_squared_error: 0.0383 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0413
# Epoch 101/150
# 673/673 [==============================] - 24s 36ms/step - loss: 0.0015 - root_mean_squared_error: 0.0384 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0412
# Epoch 102/150
# 673/673 [==============================] - 25s 37ms/step - loss: 0.0015 - root_mean_squared_error: 0.0383 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0411
# Epoch 103/150
# 673/673 [==============================] - 24s 36ms/step - loss: 0.0015 - root_mean_squared_error: 0.0383 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0411
# Epoch 104/150
# 673/673 [==============================] - 24s 36ms/step - loss: 0.0015 - root_mean_squared_error: 0.0383 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0410
# Epoch 105/150
# 673/673 [==============================] - 24s 36ms/step - loss: 0.0015 - root_mean_squared_error: 0.0383 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0412
# Epoch 106/150
# 673/673 [==============================] - 24s 36ms/step - loss: 0.0015 - root_mean_squared_error: 0.0383 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0415
# Epoch 107/150
# 673/673 [==============================] - 25s 37ms/step - loss: 0.0015 - root_mean_squared_error: 0.0383 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0412
# Epoch 108/150
# 673/673 [==============================] - 24s 36ms/step - loss: 0.0015 - root_mean_squared_error: 0.0382 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0412
# Epoch 109/150
# 673/673 [==============================] - 24s 35ms/step - loss: 0.0015 - root_mean_squared_error: 0.0382 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0412
# Epoch 110/150
# 673/673 [==============================] - 24s 35ms/step - loss: 0.0015 - root_mean_squared_error: 0.0383 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0412
# Epoch 111/150
# 673/673 [==============================] - 24s 35ms/step - loss: 0.0015 - root_mean_squared_error: 0.0382 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0412
# Epoch 112/150
# 673/673 [==============================] - 24s 36ms/step - loss: 0.0015 - root_mean_squared_error: 0.0383 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0412
# Epoch 113/150
# 673/673 [==============================] - 24s 36ms/step - loss: 0.0015 - root_mean_squared_error: 0.0382 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0412
# Epoch 114/150
# 673/673 [==============================] - 24s 36ms/step - loss: 0.0015 - root_mean_squared_error: 0.0383 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0410
# Epoch 115/150
# 673/673 [==============================] - 25s 36ms/step - loss: 0.0015 - root_mean_squared_error: 0.0382 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0412
# Epoch 116/150
# 673/673 [==============================] - 25s 37ms/step - loss: 0.0015 - root_mean_squared_error: 0.0382 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0413
# Epoch 117/150
# 673/673 [==============================] - 25s 37ms/step - loss: 0.0015 - root_mean_squared_error: 0.0382 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0412
# Epoch 118/150
# 673/673 [==============================] - 25s 37ms/step - loss: 0.0015 - root_mean_squared_error: 0.0383 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0410
# Epoch 119/150
# 673/673 [==============================] - 24s 35ms/step - loss: 0.0015 - root_mean_squared_error: 0.0382 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0413
# Epoch 120/150
# 673/673 [==============================] - 24s 35ms/step - loss: 0.0015 - root_mean_squared_error: 0.0382 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0412
# Epoch 121/150
# 673/673 [==============================] - 24s 35ms/step - loss: 0.0015 - root_mean_squared_error: 0.0383 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0411
# Epoch 122/150
# 673/673 [==============================] - 24s 36ms/step - loss: 0.0015 - root_mean_squared_error: 0.0382 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0413
# Epoch 123/150
# 673/673 [==============================] - 24s 35ms/step - loss: 0.0015 - root_mean_squared_error: 0.0382 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0412
# Epoch 124/150
# 673/673 [==============================] - 24s 36ms/step - loss: 0.0015 - root_mean_squared_error: 0.0382 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0410
# Epoch 125/150
# 673/673 [==============================] - 24s 36ms/step - loss: 0.0015 - root_mean_squared_error: 0.0388 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0413
# Epoch 126/150
# 673/673 [==============================] - 24s 36ms/step - loss: 0.0015 - root_mean_squared_error: 0.0382 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0413
# Epoch 127/150
# 673/673 [==============================] - 24s 36ms/step - loss: 0.0015 - root_mean_squared_error: 0.0381 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0412
# Epoch 128/150
# 673/673 [==============================] - 24s 36ms/step - loss: 0.0015 - root_mean_squared_error: 0.0382 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0413
# Epoch 129/150
# 673/673 [==============================] - 25s 37ms/step - loss: 0.0015 - root_mean_squared_error: 0.0382 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0412
# Epoch 130/150
# 673/673 [==============================] - 25s 36ms/step - loss: 0.0015 - root_mean_squared_error: 0.0382 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0412
# Epoch 131/150
# 673/673 [==============================] - 24s 36ms/step - loss: 0.0015 - root_mean_squared_error: 0.0381 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0413
# Epoch 132/150
# 673/673 [==============================] - 25s 37ms/step - loss: 0.0015 - root_mean_squared_error: 0.0382 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0413
# Epoch 133/150
# 673/673 [==============================] - 25s 37ms/step - loss: 0.0015 - root_mean_squared_error: 0.0384 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0413
# Epoch 134/150
# 673/673 [==============================] - 25s 37ms/step - loss: 0.0015 - root_mean_squared_error: 0.0381 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0413
# Epoch 135/150
# 673/673 [==============================] - 25s 37ms/step - loss: 0.0015 - root_mean_squared_error: 0.0381 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0412
# Epoch 136/150
# 673/673 [==============================] - 26s 39ms/step - loss: 0.0015 - root_mean_squared_error: 0.0382 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0413
# Epoch 137/150
# 673/673 [==============================] - 25s 37ms/step - loss: 0.0015 - root_mean_squared_error: 0.0381 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0415
# Epoch 138/150
# 673/673 [==============================] - 25s 37ms/step - loss: 0.0015 - root_mean_squared_error: 0.0382 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0414
# Epoch 139/150
# 673/673 [==============================] - 26s 38ms/step - loss: 0.0015 - root_mean_squared_error: 0.0381 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0413
# Epoch 140/150
# 673/673 [==============================] - 26s 39ms/step - loss: 0.0015 - root_mean_squared_error: 0.0381 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0414
# Epoch 141/150
# 673/673 [==============================] - 25s 38ms/step - loss: 0.0015 - root_mean_squared_error: 0.0382 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0414
# Epoch 142/150
# 673/673 [==============================] - 25s 37ms/step - loss: 0.0015 - root_mean_squared_error: 0.0384 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0411
# Epoch 143/150
# 673/673 [==============================] - 25s 37ms/step - loss: 0.0015 - root_mean_squared_error: 0.0381 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0412
# Epoch 144/150
# 673/673 [==============================] - 25s 38ms/step - loss: 0.0015 - root_mean_squared_error: 0.0381 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0411
# Epoch 145/150
# 673/673 [==============================] - 25s 38ms/step - loss: 0.0015 - root_mean_squared_error: 0.0381 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0413
# Epoch 146/150
# 673/673 [==============================] - 25s 37ms/step - loss: 0.0014 - root_mean_squared_error: 0.0381 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0411
# Epoch 147/150
# 673/673 [==============================] - 25s 37ms/step - loss: 0.0015 - root_mean_squared_error: 0.0382 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0413
# Epoch 148/150
# 673/673 [==============================] - 25s 37ms/step - loss: 0.0014 - root_mean_squared_error: 0.0381 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0413
# Epoch 149/150
# 673/673 [==============================] - 25s 37ms/step - loss: 0.0014 - root_mean_squared_error: 0.0381 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0414
# Epoch 150/150
# 673/673 [==============================] - 25s 37ms/step - loss: 0.0014 - root_mean_squared_error: 0.0381 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0412
# INFO:tensorflow:Assets written to: ./gdrive/My Drive/data/CSC/W4/W4633070102_encoded/assets

# %%
if retrain:
    fig, ax = plt.subplots(figsize=(10,5))

    ax.plot(lstm_ae_model.history['loss'], marker='.', label='loss')
    ax.plot(lstm_ae_model.history['val_loss'], marker='.', label='validation loss')

    ax.legend()
    ax.grid(True)

    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.savefig('epoches.png', dpi=300)
    plt.show()

# %%
synthetic_pd = pd.DataFrame.from_records([i[0] for i in synthetic_data])

# %% [markdown]
# # Validation

# %% [markdown]
# ## PCA

# %%
from sklearn.decomposition import PCA

pca_scale = PCA(n_components=2)
pca_scale = pca_scale.fit(X_source)

X_source_dr = pca_scale.transform(X_source)
x_min, x_max = X_source_dr.min(0), X_source_dr.max(0)
X_norm = (X_source_dr-x_min) / (x_max-x_min)  #Normalize
X_source_df = pd.DataFrame(X_norm, columns = ['dim1','dim2'])

X_target_dr = pca_scale.transform(X_target)
x_min, x_max = X_target_dr.min(0), X_target_dr.max(0)
X_norm = (X_target_dr-x_min) / (x_max-x_min)  #Normalize
X_target_df = pd.DataFrame(X_norm, columns = ['dim1','dim2'])

X_decoder_dr = pca_scale.transform(synthetic_pd)
x_min, x_max = X_decoder_dr.min(0), X_decoder_dr.max(0)
X_norm = (X_decoder_dr-x_min) / (x_max-x_min)  #Normalize
X_decode_df = pd.DataFrame(X_norm, columns = ['dim1','dim2'])

# %%
fig, ax = plt.subplots(figsize=(10,5))

ax.scatter(X_source_df['dim1'], X_source_df['dim2'], alpha=0.1, label='source')
ax.scatter(X_target_df['dim1'], X_target_df['dim2'], alpha=0.1, label='target')
ax.scatter(X_decode_df['dim1'], X_decode_df['dim2'], alpha=0.1, label='synthetic')

ax.legend()
ax.grid(True)

#plt.ylim(0, 1)
#plt.xlim(0, 1)
plt.savefig('distribution.png', dpi=300)
plt.show()

# %% [markdown]
# ## Model Cross Validation

# %%
model_source = svm.OneClassSVM(nu=0.01, kernel="rbf", gamma=0.01).fit(X_source)
model_target = svm.OneClassSVM(nu=0.01, kernel="rbf", gamma=0.01).fit(X_target)
model_synthetic = svm.OneClassSVM(nu=0.01, kernel="rbf", gamma=0.01).fit(synthetic_pd)

# %%
def scorer_(Y_pred):
    a = (Y_pred[Y_pred == -1].size)/(Y_pred.size)
    return a*100

# %%
def plot_score (score_list, date_list, tag):

    fig, ax = plt.subplots(figsize=(10, 3))
    plt.xticks(rotation=45)
    ax.plot(date_list, score_list, '.-')
    ax.set(xlabel='date', ylabel='score', title=tag)
    ax.grid()
    plt.ylim(0, 100)
    plt.tight_layout()
    #fig.savefig(path+tag+'-'+training_from.strftime("%Y%m%d")+'-'+training_to.strftime("%Y%m%d")+'.png', dpi=300)
    plt.show()

# %%
def get_score (data_df, start_date, end_date, normalizer, prediction_model):

    score_list = []
    date_list = []
    delta = datetime.timedelta(days=1)

    while start_date <= end_date:

        validation_df = data_df[(data_df['datetime'] > start_date) & 
                                (data_df['datetime'] <= start_date + delta)]

        
        if len(validation_df) > 0:

            validation_df_score = validation_df.drop(columns=drop_list)
            validation_df_score = normalizer.transform(validation_df_score)
            validation_df_score = prediction_model.predict(validation_df_score)

            score_list.append(scorer_(validation_df_score))
            date_list.append(start_date)

        start_date += delta
        
    return score_list, date_list

# %%
target_score_cv, target_date_cv = get_score(globals()[tag_dict['target']], 
                                            tag_dict['target_training_from'], 
                                            tag_dict['target_end'], 
                                            normalizer,
                                            model_source)

target_score, target_date = get_score(globals()[tag_dict['target']], 
                                            tag_dict['target_training_from'], 
                                            tag_dict['target_end'], 
                                            normalizer,
                                            model_target)

target_score_da, target_date_da = get_score(globals()[tag_dict['target']], 
                                            tag_dict['target_training_from'], 
                                            tag_dict['target_end'], 
                                            normalizer,
                                            model_synthetic)

# %%
def rmse(predictions, targets):
    return np.sqrt(((predictions - targets) ** 2).mean())

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(target_score_cv, target_score, squared=False)
# Out:
# 98.096683027771

# %%
da_rmse = mean_squared_error(target_score_da, target_score, squared=False)
cv_rmse = mean_squared_error(target_score_cv, target_score, squared=False)



plot_score (target_score, target_date, 'Detect ' + tag_dict['target'] +' conditions by using '+ tag_dict['target'] +' model')

plot_score (target_score_cv, 
            target_date_cv, 
            'Detect ' + tag_dict['target'] +' conditions by using '+ tag_dict['source'] +' model, RMSE='+ "{:.3f}".format(cv_rmse))

plot_score (target_score_da, 
            target_date_da, 
            'Detect ' + tag_dict['target'] +' conditions by using '+ tag_dict['source'] +' synthetic model, RMSE=' + "{:.3f}".format(da_rmse))

# %% [markdown]
# ## Check Synthetic Data

# %%
feature_index = 206
duration = 26000
interval = 100
fig, ax = plt.subplots(figsize=(10,5))

ax.plot(range(duration, duration+interval), X_target[feature_index].head(duration).tail(interval), label='target', marker='.')
ax.plot(range(duration, duration+interval), X_source[feature_index].head(duration).tail(interval), label='source', marker='.')
ax.plot(range(duration, duration+interval), synthetic_pd[feature_index].head(duration).tail(interval), label='synthetic', marker='.')

ax.legend()
ax.grid(True)
plt.tight_layout()

#plt.savefig('distribution.png', dpi=300)
plt.show()
